# %%
import sqlite3
import pandas as pd

with sqlite3.connect('input/quests.db') as conn:
    df = pd.read_sql_query("SELECT * FROM quests", conn)

df.head()
# Out:
#    id expansion                   title_en  \
# 0   2   classic          Sharptalon's Claw
# 1   5   classic      Jitters' Growling Gut
# 2   6   classic  Bounty on Garrick Padfoot
# 3   7   classic        Kobold Camp Cleanup
# 4   8   classic             A Rogue's Deal
#
#                                         objective_en  \
# 0  Bring Sharptalon's Claw to Senani Thunderheart...
# 1                             Speak with Chef Grual.
# 2  Kill Garrick Padfoot and bring his head to Dep...
# 3  Kill 10 Kobold Vermin, then return to Marshal ...
# 4  Deliver the Nondescript Letter to Innkeeper Re...
#
#                                       description_en  \
# 0  The mighty hippogryph Sharptalon has been slai...
# 1  I've been stuck hiding in this ghost town for ...
# 2  Garrick Padfoot - a cutthroat who's plagued ou...
# 3  Your first task is one of cleansing, <name>. A...
# 4  Hey, mate! Do a favor for a young man who's be...
#
#                                          progress_en  \
# 0  Yes, mighty <class>, I sensed your arrival. I ...
# 1                                               None
# 2  Did you find Garrick's shack? Are we finally f...
# 3  How goes the hunting, <name>? Have you found a...
# 4  Yes? Yes? What is it?\n\nThe forsaken; they ce...
#
#                                        completion_en  \
# 0  Most impressive, <name>... the claw of Sharpta...
# 1  You need some Crab Cakes, do you? Well I might...
# 2  Hah - you caught him! You've done Elwynn a gre...
# 3  Well done, citizen. Those kobolds are thieves ...
# 4  Oh? A letter? Wonderful news! I've been waitin...
#
#                                   title_uk  \
# 0                      Кіготь Гостропазура
# 1            Бурчання Тремтінієвого живота
# 2  Винагорода за голову Ґарріка М'якоступа
# 3                Зачистка табору кобольдів
# 4                        Угода пройдисвіта
#
#                                         objective_uk  \
# 0  Принесіть кіготь Гостропазура до Сенані Грозов...
# 1                  Поговоріть з шеф-кухарем Ґруалем.
# 2  Убийте Ґарріка М'якоступа та принесіть його го...
# 3  Убийте 10 кобольдів-шкідників, а потім поверні...
# 4  Доставте непідписаний лист корчмарці Рені в Ті...
#
#                                       description_uk  \
# 0  Могутнього Гостропазура вбито, а кіготь гіпогр...
# 1  Я вже декілька тижнів ховаюсь в цьому містечку...
# 2  Ґаррік М'якоступ — головоріз, який мучить наши...
# 3  Твоє перше завдання буде пов'язане із зачищенн...
# 4  Гей, {стать:приятелю:приятелько}! Зроби-но пос...
#
#                                          progress_uk  \
# 0  Так, {стать:могутній:могутня} {клас:к}, я відч...
# 1                                               None
# 2  Ти {стать:знайшов:знайшла} халупу Ґарріка? Нев...
# 3  Як там твоє полювання, {ім'я:к}? Ти {стать:зна...
# 4  Так? Так? Що це?\n\nВідречені. У них, безумовн...
#
#                                        completion_uk  \
# 0  Я вражена, {ім'я:к}... кіготь Гостропазура — н...
# 1  Хочеш крабових пиріжків? Ну, я можу приготуват...
# 2  Ха-а — ти {стать:спіймав:спіймала} його! Ти {с...
# 3  Молодець, {стать:громадянине:громадянко}. Ці к...
# 4  Га? Лист? Гарні новини! Я так чекала на звістк...
#
#                                 cat
# 0                Kalimdor/Ashenvale
# 1         Eastern Kingdoms/Duskwood
# 2    Eastern Kingdoms/Elwynn Forest
# 3    Eastern Kingdoms/Elwynn Forest
# 4  Eastern Kingdoms/Tirisfal Glades

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15775 entries, 0 to 15774
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              15775 non-null  int64
#  1   expansion       15775 non-null  object
#  2   title_en        15775 non-null  object
#  3   objective_en    14249 non-null  object
#  4   description_en  14255 non-null  object
#  5   progress_en     9832 non-null   object
#  6   completion_en   15256 non-null  object
#  7   title_uk        6346 non-null   object
#  8   objective_uk    5449 non-null   object
#  9   description_uk  5447 non-null   object
#  10  progress_uk     4703 non-null   object
#  11  completion_uk   6230 non-null   object
#  12  cat             15775 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.6+ MB

# %%
translated = df[df['title_uk'].notnull()]
untranslated = df[df['title_uk'].isnull()]
# translated.head()
translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6346 entries, 0 to 10325
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              6346 non-null   int64
#  1   expansion       6346 non-null   object
#  2   title_en        6346 non-null   object
#  3   objective_en    5449 non-null   object
#  4   description_en  5447 non-null   object
#  5   progress_en     4704 non-null   object
#  6   completion_en   6233 non-null   object
#  7   title_uk        6346 non-null   object
#  8   objective_uk    5449 non-null   object
#  9   description_uk  5447 non-null   object
#  10  progress_uk     4703 non-null   object
#  11  completion_uk   6230 non-null   object
#  12  cat             6346 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 694.1+ KB

# %%
# untranslated.head()
untranslated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9429 entries, 5078 to 15774
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              9429 non-null   int64
#  1   expansion       9429 non-null   object
#  2   title_en        9429 non-null   object
#  3   objective_en    8800 non-null   object
#  4   description_en  8808 non-null   object
#  5   progress_en     5128 non-null   object
#  6   completion_en   9023 non-null   object
#  7   title_uk        0 non-null      object
#  8   objective_uk    0 non-null      object
#  9   description_uk  0 non-null      object
#  10  progress_uk     0 non-null      object
#  11  completion_uk   0 non-null      object
#  12  cat             9429 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 1.0+ MB

# %%
english_columns = ['title_en', 'objective_en', 'description_en', 'progress_en', 'completion_en']
ukrainian_columns = ['title_uk', 'objective_uk', 'description_uk', 'progress_uk', 'completion_uk']

incomplete_translations = df[(df[ukrainian_columns].notnull().sum(axis=1) > 0) & (df[ukrainian_columns].notnull().sum(axis=1) != df[english_columns].notnull().sum(axis=1))]
empty_quests = df[df[['objective_en', 'description_en', 'progress_en', 'completion_en']].isnull().all(axis=1)]

df_cleaned = df.drop([*incomplete_translations.index, *empty_quests.index])

print(len(incomplete_translations))
print(len(empty_quests))
df_cleaned.info()
# Out:
# 4
# 42
# <class 'pandas.core.frame.DataFrame'>
# Index: 15729 entries, 0 to 15774
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              15729 non-null  int64
#  1   expansion       15729 non-null  object
#  2   title_en        15729 non-null  object
#  3   objective_en    14245 non-null  object
#  4   description_en  14251 non-null  object
#  5   progress_en     9831 non-null   object
#  6   completion_en   15252 non-null  object
#  7   title_uk        6337 non-null   object
#  8   objective_uk    5445 non-null   object
#  9   description_uk  5443 non-null   object
#  10  progress_uk     4703 non-null   object
#  11  completion_uk   6229 non-null   object
#  12  cat             15729 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.7+ MB

# %%
incomplete_translations
# Out:
#           id expansion           title_en  \
# 7528    1046     wrath  Raene's Cleansing
# 10311  78136     wrath    A New Beginning
# 10312  78137     wrath    A New Beginning
# 10313  78138     wrath    A New Beginning
#
#                                             objective_en  \
# 7528   Bring Ran Bloodtooth's Skull to Raene Wolfrunn...
# 10311          Meet with a <class> trainer in Stormwind.
# 10312          Meet with a <class> trainer in Orgrimmar.
# 10313      Meet with a <class> trainer in Thunder Bluff.
#
#                                           description_en  \
# 7528   Return to your own tribe and let them know of ...
# 10311  A letter magically appears in the lining of yo...
# 10312  A letter magically appears in the lining of yo...
# 10313  A letter magically appears in the lining of yo...
#
#                                              progress_en  \
# 7528   The Sentinels do what they can here in Ashenva...
# 10311                                               None
# 10312                                               None
# 10313                                               None
#
#                                            completion_en       title_uk  \
# 7528   So, this is the skull of the fiercest furbolg ...    Рене очищує
# 10311                   Ready for your training, <race>?  Новий початок
# 10312                   Ready for your training, <race>?  Новий початок
# 10313                           Ready for your training?  Новий початок
#
#                                             objective_uk  \
# 7528   Принесіть череп Рана Кривавозубого до Рене Вов...
# 10311   Зустріньтеся з тренером свого класу в Штормовії.
# 10312  Зустріньтеся з тренером свого класу в Орґріммарі.
# 10313  Зустріньтеся з тренером свого класу в Громовом...
#
#                                           description_uk progress_uk  \
# 7528   Повертайся до свого племені й розкажи їм про с...        None
# 10311  У підкладці ваших обладунків магічним чином з'...        None
# 10312  У підкладці ваших обладунків магічним чином з'...        None
# 10313  У підкладці ваших обладунків магічним чином з'...        None
#
#                                            completion_uk  \
# 7528   То це і є череп найлютішого хутропуза в Ясенед...
# 10311                                               None
# 10312                                               None
# 10313                                               None
#
#                                    cat
# 7528                Kalimdor/Ashenvale
# 10311  Eastern Kingdoms/Stormwind City
# 10312               Kalimdor/Orgrimmar
# 10313           Kalimdor/Thunder Bluff

# %%
# %pip install crowdin-api-client
import os
from dotenv import load_dotenv
from crowdin_api import CrowdinClient

load_dotenv()

CROWDIN_PROJECT_ID=393919
crowdin_client = CrowdinClient(token=os.getenv('CROWDIN_TOKEN'), project_id=CROWDIN_PROJECT_ID, )

# %%
expressions = [
    "Give Jitters' Completed Journal to Bishop Farthing in Stormwind.",
    """Go to the city of Stormwind and speak with Bishop Farthing in the Cathedral of Light. Give him Jitters' journal and tell him you mean to face Morbent Fel.

Although Stormwind has forsaken Darkshire, Farthing is a kind soul and very wise. He may help you on your quest to save us.

Your mission is perilous, but hurry, <name>. With each passing hour, the shadows of Duskwood grow ever darker.""",
    "Rest, brother. I can tell you have traveled far, and you bear a heavy burden. Can you tell me what casts that dark shadow over you?",
    """<After reading the journal and hearing your intent...>

An evil taint has gained a foothold within the already beleaguered Duskwood. I thank the Light we have a hero such as you to face it.

But you must first prepare yourself for the coming trial...for the Necromancer Morbent Fel is immensely powerful, and has cast dark enchantments about himself to protect him from physical assaults. If you are to defeat him, you will need a weapon that is proof against these protections."""
]

glossary_response = crowdin_client.glossaries.concordance_search_in_glossaries(sourceLanguageId='en', targetLanguageId='uk', expressions=expressions)
# glossary_response['data']
[(data['data']['sourceTerms'][0]['text'], data['data']['targetTerms'][0]['text'], data['data']['sourceTerms'][0]['description']) for data in glossary_response['data']]
# Out:
# [('Stormwind',
#   'Штормовій',
#   'локація, столиця людей, Ельвиннський ліс, Східні Королівства, ~Stormwind City~'),
#  ('Duskwood', 'Смерколісся', 'локація, Східні Королівства'),
#  ('Darkshire', 'Темноділ', 'локація, містечко, Смерколісся'),
#  ('Forsaken', 'відречені', 'група, фракція, невмерлі'),
#  ('Farthing', 'Фартинг', 'родовід, відречені'),
#  ('Cathedral of Light', 'собор Світла', 'локація, будинок'),
#  ('bishop', 'єпископ', 'ранг'),
#  ('Bishop Farthing', 'єпископ Фартинг', 'нпц, чол, людина, #1212'),
#  ('Morbent Fel', 'Морбент Скверн', 'нпц, чол, людина, #1200'),
#  ('City', 'місто', 'локація'),
#  ('Shadow', 'Тінь', 'нпц, вовк, #4244, <улюбленець Доріона>'),
#  ('Necromancer', 'некромант', 'нпц, мінорний, #8553, <Cult of the Damned>')]

# %%
# %pip install ratelimit
from datetime import timedelta
from ratelimit import limits, sleep_and_retry
# from threading import Semaphore

# semaphore = Semaphore(20)

@sleep_and_retry
@limits(calls=19, period=timedelta(seconds=1).total_seconds())
def query_glossary_api(row):
    # with semaphore:
    texts = [row['title_en'], row['objective_en'], row['description_en'], row['progress_en'], row['completion_en']]
    texts = [text for text in texts if text is not None]
    # print(texts)
    glossary_response = crowdin_client.glossaries.concordance_search_in_glossaries(sourceLanguageId='en', targetLanguageId='uk', expressions=texts)
    # terms = list(map(lambda data: (data['data']['sourceTerms'][0]['text'], data['data']['targetTerms'][0]['text'], data['data']['sourceTerms'][0]['description']), glossary_response['data']))
    terms = list(map(lambda data: {'en': data['data']['sourceTerms'][0]['text'], 'uk': data['data']['targetTerms'][0]['text']}, glossary_response['data']))
    return terms

# %%
# filtered_df = untranslated[(untranslated['expansion']=='tbc') & (untranslated['cat']=='Outland/Terokkar Forest')]
filtered_df = df_cleaned[(df_cleaned['expansion']=='cata') & (df_cleaned['cat']=='Eastern Kingdoms/Twilight Highlands')].copy()
filtered_df
# Out:
#           id expansion                    title_en  \
# 12935  26538      cata               Emergency Aid
# 12936  26539      cata        Stalled Negotiations
# 12937  26540      cata        Dangerous Compassion
# 12945  26549      cata                     Madness
# 13003  26608      cata     Negotiations Terminated
# ...      ...       ...                         ...
# 15166  28872      cata                   Total War
# 15167  28873      cata         Another Maw to Feed
# 15168  28874      cata               Hook 'em High
# 15169  28875      cata  Bring Down the High Shaman
# 15178  28885      cata    Mr. Goldmine's Wild Ride
#
#                                             objective_en  \
# 12935  Seek out a Medicine Man in Dragonmaw Port, som...
# 12936  Speak with Ornak in Dragonmaw Port. Horzog can...
# 12937  Bring the Crate of Dragonmaw Bandages back to ...
# 12945  Escort the Horde Negotiator to the main hall i...
# 13003  Return to Admiral Stonefist off the shore of D...
# ...                                                  ...
# 15166  Smash 10 Thundermar Ale Kegs within the Thunde...
# 15167  Gather 10 Wildhammer Food Stores from the Thun...
# 15168  Use the Barbed Fleshhook to dismount and kill ...
# 15169                      Slay High Shaman MacKilligan.
# 15178  Ride the mine cart with Initiate Goldmine to t...
#
#                                           description_en  \
# 12935  Many of our warriors didn't survive the Twilig...
# 12936  The Warchief's whereabouts are unknown! But we...
# 12937  The red dragonflight represents the aspect of ...
# 12945  Our last two negotiators haven't returned from...
# 13003  Go now, go back to your fleet. Tell them what ...
# ...                                                  ...
# 15166  Some of the Wildhammer still cling to the hope...
# 15167  <Griff's stomach growls.>\n\nStill hungry. It'...
# 15168  The Wildhammer can train war gryphons faster t...
# 15169  Our scouts in the field report that High Shama...
# 15178  Okay, <name>, we need to get to the earth port...
#
#                                              progress_en  \
# 12935  Speak quickly! What do you want?\n\nDon't let ...
# 12936                                               None
# 12937             Do you bring any hope for our wounded?
# 12945  <name>, I understand you're going to speak wit...
# 13003                                               None
# ...                                                  ...
# 15166                                               None
# 15167                            <Griff licks his lips.>
# 15168                                               None
# 15169                                               None
# 15178                                               None
#
#                                            completion_en title_uk  \
# 12935  <Gregor bows respectfully to Zaela.>\n\nIf it ...     None
# 12936  I'm glad you're here, <class>. Perhaps a seaso...     None
# 12937  Dragon's Blood!? We best not tell our red drag...     None
# 12945  Wake up, <name>! We don't have much time.\n\nI...     None
# 13003  The Fel Orcs from Outland have laid claim to t...     None
# ...                                                  ...      ...
# 15166  Yes, yes. Burn them out, as you would flush gr...     None
# 15167  <Griff greedily snatches the heap of food, eno...     None
# 15168  You made that look easy, <name>.\n\nGet the Wi...     None
# 15169  The High Shaman has been brought down! Thunder...     None
# 15178  Oh no! My weapons and totems!\n\nThey're destr...     None
#
#       objective_uk description_uk progress_uk completion_uk  \
# 12935         None           None        None          None
# 12936         None           None        None          None
# 12937         None           None        None          None
# 12945         None           None        None          None
# 13003         None           None        None          None
# ...            ...            ...         ...           ...
# 15166         None           None        None          None
# 15167         None           None        None          None
# 15168         None           None        None          None
# 15169         None           None        None          None
# 15178         None           None        None          None
#
#                                        cat
# 12935  Eastern Kingdoms/Twilight Highlands
# 12936  Eastern Kingdoms/Twilight Highlands
# 12937  Eastern Kingdoms/Twilight Highlands
# 12945  Eastern Kingdoms/Twilight Highlands
# 13003  Eastern Kingdoms/Twilight Highlands
# ...                                    ...
# 15166  Eastern Kingdoms/Twilight Highlands
# 15167  Eastern Kingdoms/Twilight Highlands
# 15168  Eastern Kingdoms/Twilight Highlands
# 15169  Eastern Kingdoms/Twilight Highlands
# 15178  Eastern Kingdoms/Twilight Highlands
#
# [248 rows x 13 columns]

# %%
from concurrent.futures import ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=20) as executor:
    filtered_df['glossary'] = list(executor.map(query_glossary_api, [row for _, row in filtered_df.iterrows()]))

# %%
filtered_df
# Out:
#           id expansion                    title_en  \
# 12935  26538      cata               Emergency Aid
# 12936  26539      cata        Stalled Negotiations
# 12937  26540      cata        Dangerous Compassion
# 12945  26549      cata                     Madness
# 13003  26608      cata     Negotiations Terminated
# ...      ...       ...                         ...
# 15166  28872      cata                   Total War
# 15167  28873      cata         Another Maw to Feed
# 15168  28874      cata               Hook 'em High
# 15169  28875      cata  Bring Down the High Shaman
# 15178  28885      cata    Mr. Goldmine's Wild Ride
#
#                                             objective_en  \
# 12935  Seek out a Medicine Man in Dragonmaw Port, som...
# 12936  Speak with Ornak in Dragonmaw Port. Horzog can...
# 12937  Bring the Crate of Dragonmaw Bandages back to ...
# 12945  Escort the Horde Negotiator to the main hall i...
# 13003  Return to Admiral Stonefist off the shore of D...
# ...                                                  ...
# 15166  Smash 10 Thundermar Ale Kegs within the Thunde...
# 15167  Gather 10 Wildhammer Food Stores from the Thun...
# 15168  Use the Barbed Fleshhook to dismount and kill ...
# 15169                      Slay High Shaman MacKilligan.
# 15178  Ride the mine cart with Initiate Goldmine to t...
#
#                                           description_en  \
# 12935  Many of our warriors didn't survive the Twilig...
# 12936  The Warchief's whereabouts are unknown! But we...
# 12937  The red dragonflight represents the aspect of ...
# 12945  Our last two negotiators haven't returned from...
# 13003  Go now, go back to your fleet. Tell them what ...
# ...                                                  ...
# 15166  Some of the Wildhammer still cling to the hope...
# 15167  <Griff's stomach growls.>\n\nStill hungry. It'...
# 15168  The Wildhammer can train war gryphons faster t...
# 15169  Our scouts in the field report that High Shama...
# 15178  Okay, <name>, we need to get to the earth port...
#
#                                              progress_en  \
# 12935  Speak quickly! What do you want?\n\nDon't let ...
# 12936                                               None
# 12937             Do you bring any hope for our wounded?
# 12945  <name>, I understand you're going to speak wit...
# 13003                                               None
# ...                                                  ...
# 15166                                               None
# 15167                            <Griff licks his lips.>
# 15168                                               None
# 15169                                               None
# 15178                                               None
#
#                                            completion_en title_uk  \
# 12935  <Gregor bows respectfully to Zaela.>\n\nIf it ...     None
# 12936  I'm glad you're here, <class>. Perhaps a seaso...     None
# 12937  Dragon's Blood!? We best not tell our red drag...     None
# 12945  Wake up, <name>! We don't have much time.\n\nI...     None
# 13003  The Fel Orcs from Outland have laid claim to t...     None
# ...                                                  ...      ...
# 15166  Yes, yes. Burn them out, as you would flush gr...     None
# 15167  <Griff greedily snatches the heap of food, eno...     None
# 15168  You made that look easy, <name>.\n\nGet the Wi...     None
# 15169  The High Shaman has been brought down! Thunder...     None
# 15178  Oh no! My weapons and totems!\n\nThey're destr...     None
#
#       objective_uk description_uk progress_uk completion_uk  \
# 12935         None           None        None          None
# 12936         None           None        None          None
# 12937         None           None        None          None
# 12945         None           None        None          None
# 13003         None           None        None          None
# ...            ...            ...         ...           ...
# 15166         None           None        None          None
# 15167         None           None        None          None
# 15168         None           None        None          None
# 15169         None           None        None          None
# 15178         None           None        None          None
#
#                                        cat  \
# 12935  Eastern Kingdoms/Twilight Highlands
# 12936  Eastern Kingdoms/Twilight Highlands
# 12937  Eastern Kingdoms/Twilight Highlands
# 12945  Eastern Kingdoms/Twilight Highlands
# 13003  Eastern Kingdoms/Twilight Highlands
# ...                                    ...
# 15166  Eastern Kingdoms/Twilight Highlands
# 15167  Eastern Kingdoms/Twilight Highlands
# 15168  Eastern Kingdoms/Twilight Highlands
# 15169  Eastern Kingdoms/Twilight Highlands
# 15178  Eastern Kingdoms/Twilight Highlands
#
#                                                 glossary
# 12935  [{'en': 'warchief', 'uk': 'воєвождь'}, {'en': ...
# 12936  [{'en': 'The Horde', 'uk': 'Орда'}, {'en': 'wa...
# 12937  [{'en': 'dragon', 'uk': 'дракон'}, {'en': 'Red...
# 12945  [{'en': 'The Horde', 'uk': 'Орда'}, {'en': 'wa...
# 13003  [{'en': 'admiral', 'uk': 'адмірал'}, {'en': 'w...
# ...                                                  ...
# 15166  [{'en': 'Thundermar', 'uk': 'Гріммар'}, {'en':...
# 15167  [{'en': 'Maws', 'uk': 'Пащі'}, {'en': 'The Hea...
# 15168  [{'en': 'Bloodgulch', 'uk': 'Кривава ущелина'}...
# 15169  [{'en': 'shaman', 'uk': 'шаман/шаманка'}, {'en...
# 15178                   [{'en': 'Mines', 'uk': 'Шахти'}]
#
# [248 rows x 14 columns]

# %%
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

oai_client = OpenAI(
    api_key=os.getenv('OPENAI_API_KEY')
)

TRANSLATION_SYSTEM_PROMPT = """You are a professional translator specializing in MMORPG game localization, responsible for translating World of Warcraft content from English to Ukrainian. 
You will receive a JSON file containing an "original" section with the object to translate. 
Your task is to respond with a JSON containing single section, "translation", that replicates the structure of the "original" section, replacing source text with translated values while maintaining all keys.
Use your knowledge of the Warcraft universe to ensure accuracy and immersion.

### **Guidelines**:

1. **Preserve Structure**:
   - The output JSON must retain the exact structure of the "original" section.
   - Ensure all keys remain the same while replacing values with their Ukrainian translations.

2. **Maintain Placeholders**:
   - Always replace name/race/class placeholders in the original text with curly-bracedanslated placeholders with shortened Ukrainian grammatical case after a semicolon. For `<name>`, `<race>`, `<class>` use `{ім'я:н}`, `{раса:д}`, `{клас:к}` with correct grammatical case afet semicolon.

3. **Adapt for Gender**:
   - Translate text to be suitable for both genders. For placeholders with gender-specific variations (e.g., `<his/her>`, `<priest/priestess>`) and translated words that have different gender forms use the format `{стать:male:female}` (e.g., `{стать:його:її}`, `{стать:жрець:жриця}`).
   - Gender placeholders should contain full words, so don't break words with placeholder: for example, instead of кмітлив{стать:ий:а} use {стать:кмітливий:кмітлива}
   - Gender placeholders can contain more that one word. If there's several consequent gender-specific placeholders or they are divided with small word - put tham in single placeholder. Fo example: instead of "дуже {стать:достойний:достойна} та {стать:спроможний:спроможна}" use "дуже {стать:достойний та спроможний:достойна та спроможна}"

4. **Formal and Informal Tone**:
   - **Quest `objective` field**: Translate using a formal tone, where "you" becomes "ви" and "your" becomes "ваш".
   - **Quest `description`, `progress`, and `completion` fields**: By default, translate these fields using an informal tone, where "you" becomes "ти" and "your" becomes "твій.". If text describes environment/interaction or NPC speaks to player politely using "sir", "lady" etc - use formal tone.

5. **Preserve Descriptive Formatting**:
   - Retain all text enclosed in angle brackets (`<>`) that describes the environment, character reactions, or similar narrative elements. Translate the content within the brackets but preserve their formatting.

6. **Maintain Lore and Style**:
   - Ensure the translation captures the epic, immersive tone of World of Warcraft.
   - Use established Warcraft terminology and lore-consistent language in Ukrainian.

7. **Glossaries and terminology**:
   - Always strictly refer to the translation glossary. Always use terms' translations from glossary, even if other more commonly used or recognized translations are available.
   - Use consistent terminology throughout all translations. Adhere strictly to any provided glossaries, ensuring uniformity in translating terms such as character names, locations, and game-specific items.

8. **Readability**:
   - Ensure translations are natural, engaging, and free from awkward phrasing.
   - Text should feel native and immersive for Ukrainian-speaking players.

---

### **Input Example**:

```json
{
  "original": {
    "quest": {
      "title": "Get rid of these boars",
      "objective": "Kill 12 boars and return to John at Scarlet Monastery in Silverpine Forest.",
      "description": "Reports have come in that wild boars trample our crops. We thought that other adventurer had dealt with this, <class>!\n\nI suggest that you to teach them a lesson as proof of your devotion.",
      "progress": "Have you clear our fields of wild boars?",
      "completion": "<John nods to you.>\n\nWe are pleased that you have prooved your devition, <name>. Surely now that you have made our point clear multiple times, their senseless attacks upon our crops will cease?"
    }
  }
}
```

---

### **Output Example**:

```json
{
  "translation": {
    "quest": {
      "title": "Позбудься цих вепрів",
      "objective": "Вбийте 12 вепрів і поверніться до Джона в Багряний Монастир, що в Срібнохвойному пралісі.",
      "description": "Надходять повідомлення про диких вепрів, що топчуть наші посіви. Ми думали, що інші шукачі пригод вже розібралися з цим, {клас:к}!\n\nРаджу тобі провчити їх як доказ твоєї відданості.",
      "progress": "Ти вже {стать:очистив:очистила} наші поля від диких вепрів?",
      "completion": "<Джон киває вам.>\n\nМи задоволені, що ти {стать:довів:довела} свою відданість, {ім'я:к}. Тепер, коли ми вже неодноразово довели свою точку зору, може їхні безглузді напади на наші посіви припиняться?"
    }
  }
}
```

---
"""

def generate_request_json(row):
    return {
        "original": {
            "quest": {
                "title": row["title_en"],
                "objective": row["objective_en"],
                "description": row["description_en"],
                "progress": row["progress_en"],
                "completion": row["completion_en"]
            }
        },
        "glossary": {
            "glossary": row["glossary"]
        }
    }

def translate_row(row):
    import json
    messages = [{'role': 'system', 'content': TRANSLATION_SYSTEM_PROMPT}, {'role': 'user', 'content': str(generate_request_json(row))}]
    response = oai_client.chat.completions.create(
    # model="ft:gpt-4o-2024-08-06:personal:classicua-v5:AXuONZ0V",
    model="ft:gpt-4o-2024-08-06:personal:classicua-v6:AeQq2YLn",
    messages=messages,
    response_format={"type":"json_object"},
    temperature=0.7,
    top_p=0.7
    )
    json_response = response.choices[0].message.content
    translation = json.loads(json_response)['translation']['quest']
    print(translation)
    return {
            "title_uk": translation.get("title", None),
            "objective_uk": translation.get("objective", None),
            "description_uk": translation.get("description", None),
            "progress_uk": translation.get("progress", None),
            "completion_uk": translation.get("completion", None),
    }

# %%
## Translating with pretrained model. Takes about 10 sec per quest.
translations = filtered_df.apply(translate_row, axis=1)
translations_df = pd.DataFrame(translations.tolist(), index=filtered_df.index)
filtered_df.update(translations_df)
# Out:
# {'title': 'Невідкладна допомога', 'objective': 'Знайдіть знахаря в порту Драконової Пащі десь біля берега.', 'description': "Багато наших воїнів не пережили атаки Сутінкового Молота на наш повітряний флот. Ті, що вижили, пливуть до решток флотилії, стікаючи кров'ю та з важкими опіками. Мені потрібна підтримка з берега, щоб врятувати моїх людей!\n\nУ порту Драконової Пащі має бути якийсь лікар чи знахар, який захоче допомогти своїм побратимам-оркам. Висаджуйся на берег і спробуй знайти ліки та повернутись з ними до флотилії!", 'progress': 'Говори швидше! Що тобі потрібно?\n\nНе дай воєвождю побачити, що ми розмовляємо...', 'completion': '<Грегор шанобливо вклоняється Заелі.>\n\nЯкщо це бажання Заели, ти отримаєш припаси. Тільки не кажи воєвождю Драконової Пащі...'}
# {'title': 'Зірвані перемовини', 'objective': 'Поговоріть з Орнаком в порту Драконової Пащі. Хорзог може швидко доставити вас на берег.', 'description': "Нам невідомо, де перебуває вождь! Але ми повинні продовжувати виконувати його план. {Ім'я:к}, ти виглядаєш {стать:тим:тією}, хто вміє виконувати доручення.\n\nНаші перемовини з кланом Драконової Пащі зірвалися. Їхній воєвождь... не такий, як ми очікували. Ти {стать:повинен:повинна} піти туди та відновити перемовини.\n\nЗустрінься з Орнаком на березі, він розповість тобі подробиці.\n\nПоговори з Хорзогом на палубі, він швидко доставить тебе на берег.", 'progress': None, 'completion': 'Я радий, що ти {стать:тут:тут}, {клас:к}. Можливо, {стать:досвідчений ветеран:досвідчена ветеранка} походів Орди в Нортренд та інші місця зможе переконати керівництво Драконової Пащі...'}
# {'title': 'Небезпечне співчуття', 'objective': 'Принесіть ящик бинтів клану Драконової Пащі воєводі Кроґу на узбережжя порту Драконової Пащі.', 'description': "Крило червоних драконів уособлює життя. Тому їхня кров має цілющі властивості.\n\nЦі бинти просочені кров'ю червоного дракона. Це останнє, що я можу дати. Нехай вони допоможуть вашим воїнам швидше одужати.\n\nЯким би не був результат ваших переговорів, не забувайте, що у вас є друзі в клані Драконової Пащі.", 'progress': 'Чи є у наших поранених надія?', 'completion': 'Кров дракона!? Краще не говорити нашим союзникам з Крила червоних драконів, що ми використовували їхню кров.\n\nЦе дуже потужна магія... Наші війська скоро повернуться в стрій.'}
# {'title': 'Божевілля', 'objective': "Доведіть парламентера Орди до головного залу порту Драконової Пащі, щоб він зустрівся з воєвождем Мор'ґором. Якщо ви втратите парламентера, поговоріть з Орнаком на узбережжі.", 'description': 'Наші останні два парламентери не повернулися після розмови з воєвождем Драконової Пащі. Думаю, нам доведеться трохи наполягти на своєму.\n\nЦього разу я хочу, щоб ти {стать:супроводжував:супроводжувала} парламентера. Коли їхній воєвождь зрозуміє, що Орда сповнена таких загартованих у боях героїв, як ти, він двічі подумає, перш ніж щось робити.\n\nПросто проведи нашого парламентера до головного залу в центрі порту Драконової Пащі та виглядай {стать:загрозливо:загрозливою}.', 'progress': "{ім'я:к}, я знаю, що ти збираєшся поговорити з нашим «воєвождем» про вступ до Орди.\n\nБудь {стать:обережним:обережною}, {клас:к}.\n\nПоговори зі мною, коли все закінчиться...", 'completion': "Прокидайся, {ім'я:к}! У нас мало часу.\n\nЯ врятував твоє спорядження.\n\nПринаймні, тепер ти {стать:побачив:побачила} безглуздість нашого лідера на власні очі. Його кров отруєна, його лють невгамовна, і він знищить нас усіх, намагаючись перемогти Орду!"}
# {'title': 'Переговори зірвано', 'objective': "Поверніться до адмірала Кам'яного Кулака на узбережжя Драконової Пащі, що в Сутінковій верховині.", 'description': 'Іди, повертайся до свого флоту. Розкажи їм, яке чудовисько претендує на владу над Драконовою Пащою.\n\nНаш "воєвождь" — зрадник своєї крові. Відтоді, як він повернувся з Позамежжя, від нього тхне демоном, і він веде те, що залишилося від нашого клану, до загибелі.\n\nДопоможи Драконовій Пащі позбутися Мор\'гора, і ті з нас, хто має чисту кров, будуть твоїми союзниками назавжди. Я обіцяю це.', 'progress': None, 'completion': 'Орки Скверни з Позамежжя претендують на Драконову Пащу? Це неприпустимо!\n\nЯкби Пеклокрик знав, що тут відбувається, він би зрівняв їхнє місто з землею...'}
# {'title': 'Революція!', 'objective': 'Прослизніть через передову в порт Драконової Пащі та поговоріть з Заелою.', 'description': "Якщо це правда, {ім'я:к}, то у нас є друзі в клані Драконової Пащі. Ми можемо підтримати повстання зсередини та уникнути великої кількості жертв з обох сторін.\n\nЯ можу допомогти, але найнебезпечнішу частину роботи доведеться виконати тобі.\n\nМої воїни з Сокирощелепого клану розпочнуть наступ на берегах. Поки буде паніка, ти прослизнеш за лінію фронту та поговориш з Заелою.\n\nМи озброїмо клан Драконової Пащі та скинемо їхніх скверновладних господарів!", 'progress': None, 'completion': "{ім'я:к}, що роблять твої союзники? Вони атакують клан Драконової Пащі чи намагаються позбавити нас від скверни Мор'гора?\n\n<Заела сміється.>\n\nА, тепер зрозуміло. Мені подобається твій підхід. Воєвождь Мор'гор навіть не зрозуміє, що його вразило.\n\nЗа справу!"}
# {'title': 'Повстання', 'objective': 'Озбройте 3 працівників або торговців клану Драконової Пащі, потім вбийте 10 громил і 4 чорнокнижників клану Драконової Пащі.', 'description': "Зброї, яку надала нам Орда, буде більш ніж достатньо. Ми вчотирьох розділимося та озброїмо якомога більше працівників та торговців клану Драконової Пащі.\n\nНе недооцінюй нас, {ім'я:к}. Навіть наші торговці люті в бою.\n\nЗавдамо якомога більше шкоди. Озброй загін клану Драконової Пащі та знищ нечистих громил і чорнокнижників, які так довго залякували мій народ. Потім повертайся сюди, щоб завдати останнього удару!", 'progress': 'Нарешті революція!\n\nДраконова Паща нарешті скидає кайдани нечисті, яка тримала нас у страху!', 'completion': "Ми втратили багато хороших орків, але бій йде за нашим сценарієм, {ім'я:к}.\n\nРежим Мор'ґора руйнується. Залишилося лише знищити цього звіра."}
# {'title': "Смерть Мор'ґору", 'objective': "Убийте воєвождя Мор'ґора в порту Драконової Пащі. Ви також можете завербувати торговців та робітників клану Драконової Пащі, щоб вони допомогли вам.", 'description': "Прийшов час. Мор'ґор помре сьогодні.\n\n{стать:Попереджаю тебе:Попереджаю тебе,} {клас:к}. У його нікчемних жилах тече кров демонів і він володіє надприродною силою. Він буде знищений, але це буде нелегкий бій.\n\nТи пам'ятаєш, де живе Мор'ґор, на вершині табору. Я зустріну тебе там. Добий його!\n\nЯкщо тобі не вистачає трьох послідовників Драконової Пащі, обов'язково завербуй їх — нам знадобиться їхня допомога.", 'progress': None, 'completion': "Молодець, {ім'я:к}! Ти {стать:зробив:зробила} Орду сильнішою під час моєї відсутності.\n\nДраконова Паща приєдналася до нас, і Зела тепер їхній новий лідер. Пролилася кров, але втрати були невеликі, а їхня вірність повна.\n\nНаша Орда стає сильнішою!"}
# {'title': 'Забруднені води', 'objective': 'Вбийте забруднених водяних елементалів та зберіть 5 вихрових ядер.', 'description': "Сили елементалів дуже сильні тут, у нагір'ї, {ім'я:к}. Саме тому Сутінковий Молот вирішив побудувати тут свій оплот.\n\nЯкщо цю енергію направити в потрібне русло, то можна зробити щось корисне... Наприклад, портал прямо в Орґріммар.\n\nНа північний захід звідси, в дельті річки Веррал, водяні елементалі збунтувалися через дії наших ворогів. Знищи їх та збери 5 вихрових ядер. Це не лише заспокоїть річку, але й допоможе нам з порталом.", 'progress': 'Сподіваюся, битва в річці була не надто небезпечною.', 'completion': 'Це ідеально! Тепер неспокійні води тієї річки зможуть робити набагато більше, ніж просто переносити мул чи каміння... Вони зможуть перенести тебе на інший континент.\n\nЗавершуй свої справи тут, у Драконовій Пащі, а потім ми зможемо продовжити.'}
# {'title': 'Закріплення плацдарму', 'objective': 'Поговоріть з Артешем в порту Драконової Пащі, що на Сутінковій верховині.', 'description': "Мене щось непокоїть, {ім'я:к}. Дракони Сутінкового Молота знали, де і коли атакувати наш повітряний флот. Наче вони знали наші плани.\n\nСеред нас є шпигуни Сутінкового Молота!\n\nЯ візьму один з наших кораблів, що залишилися, і повернуся до Орґріммара, щоб знести кілька голів. А ти залишишся тут і захистиш цей фронт. Шамани Драконової Пащі сильні, я попросив їх відкрити портал в Орґріммар, і мені потрібна твоя допомога.\n\nОтже, починай допомагати!", 'progress': 'Я не можу ні про що думати, крім шпигунів Сутінкового Молота. Мені потрібна твоя допомога.', 'completion': "Твій воєвождь рішучий, {ім'я:к}. Він добивається свого. Він мені подобається.\n\nА тепер поговорімо про портал, який він хоче!"}
# {'title': 'Закріплення нашої перемоги', 'objective': 'Зберіть 10 куп річкового мулу Веррал.', 'description': "Наш союз з Драконовою Пащою скріплено, але цей порт ще не готовий до бою. Ці кволі дерев'яні стіни — ганьба для воєвождя.\n\nКоли водяні елементалі прокладають собі шлях крізь скелі, як це було в річці Веррал, вони створюють особливий вид мулу. Він легко розтікається, а коли висихає, стає міцнішим за камінь. Це ідеальний розчин для будівництва.\n\nВирушай в дельту річки, що на північному заході звідси, та добудь трохи мулу Веррал. Навіть невелика його кількість піде на користь.", 'progress': 'Ти {стать:приніс:принесла} мул? Будівництво нових стін вже розпочалось!', 'completion': "<Орнак дивиться, як мул стікає з його пальців.>\n\nОсь це те, що треба! Я почну змішувати його з гравієм та водою. Кількох жмень цього мулу вистачить, щоб зміцнити цемент для цілої кам'яної вежі.\n\nУ нас великі плани на цей порт, {ім'я:к}. Ти все побачиш!"}
# {'title': 'Воєвождь буде задоволений', 'objective': 'Скористайтеся порталом в порту Драконової Пащі, щоб потрапити в Орґріммар і доповісти про все Ґаррошу Пеклокрику.', 'description': "Портал готовий!\n\nВін недостатньо потужний, щоб переправити армію, але ми можемо підтримувати зв'язок досить довго, щоб важливі особи могли пройти туди й назад.\n\nВоєвождь захоче дізнатися про наші успіхи. Пройди через портал в Орґріммар і розкаж про все Ґаррошу Пеклокрику.", 'progress': None, 'completion': '{Клас:к}, ти {стать:повернувся:повернулася} з Драконової Пащі. Отже, портал працює? Чудово.\n\nПерш ніж ти повернешся до роботи там, нам потрібно зайнятися брудними справами тут, в Орґріммарі...'}
# {'title': 'Повернення до верховини', 'objective': 'Скористайтеся порталом до Сутінкової верховини в Орґріммарі, щоб повернутися в порт Драконової Пащі та поговорити з Заелою.', 'description': 'Орґріммар у безпеці, наші союзники з Драконової Пащі за нами, тож ми можемо зосередитися на завоюванні Сутінкової верховини та повному знищенні сил Смертекрила.\n\nМені потрібні найкращі з Орди на передовій. А це означає ти. І всі твої друзі.\n\nВерховина БУДЕ нашою!\n\nСкористайся новим порталом, щоб повернутися в порт Драконової Пащі. Доповідь Заелі, щоб дізнатися, де ти найбільше потрібен.', 'progress': None, 'completion': "{Ім'я:к}! Сподіваюсь, в Орґріммарі все добре?\n\nЯк бачиш, будівництво порту Драконової Пащі продовжується шаленими темпами. Якщо мій народ раніше сумнівався в могутності Орди... то, побачивши цю величну споруду і швидкість, з якою вона була збудована, вони більше не сумніваються.\n\nДля Драконової Пащі настає новий день."}
# {'title': 'Рятувальна операція', 'objective': 'Знайдіть 8 ящиків з вцілілими припасами на Обсидіанових рифах.', 'description': 'Орда та наги знищили наш флот. Ми не можемо повернути тих, хто віддав своє життя в морі, але я потону, якщо дозволю нашим припасам зникнути назавжди.\n\nПопливи на Обсидіанові рифи, що на південному заході від Високого берега, та дістань наші припаси з уламків та дна океану.', 'progress': 'Скільки тобі вдалося врятувати?', 'completion': "Ти тільки поглянь на це! Ти {стать:зміг:змогла} врятувати набагато більше, ніж я думав. Ми можемо спорядити цим цілий загін морських піхотинців.\n\nСпорядження в нас є. Якби ж у нас був спосіб збільшити нашу чисельність тут, у нагір'ї..."}
# {'title': 'Підкріплення наги', 'objective': 'Вбийте 10 мірмідонів або закликачів моря з племені Чорної Луски.', 'description': "Вони виповзли з глибин океану, {ім'я:к}. Наги. Думаю, вони хочуть підкріпити Бастіон Сутінків, ймовірно, пройшовши вглиб материка річкою Веррал. Ми не можемо цього допустити!\n\nПокажи їм, що тепер це наші береги та відправ їх назад у безпросвітні глибини.\n\nВбий наг з племені Чорної Луски, що повзуть крізь Обсидіанові рифи!", 'progress': None, 'completion': "Це змусить їх забратися звідси, {ім'я:к}! Тепер Чо'галл не зможе розраховувати на підтримку наг. Зараз ми б'ємося лише з Сутінковим Молотом.\n\n\n\n...І Ордою."}
# {'title': 'Пісня сирени', 'objective': "Убийте Офелію, сирену з нагір'я.", 'description': "Вона все ще десь там... Офелія, сирена з нагір'я! Її жахлива пісня заманить тебе в глибини. Я пообіцяв залишитися та помститися за своїх полеглих товаришів по команді, {клас:к}. Якщо хочеш приєднатися до мене, просто скажи.\n\nМи прив'яжемо себе до щогли. Заплющимо очі. Позатикаємо вуха воском. А коли її ілюзія розвіється... ми завдамо удару.\n\nТи з нами?", 'progress': None, 'completion': "Вона зачарувала мене, {ім'я:к}. Якби не ти, я б не вибрався звідти живим. Дякую!\n\nМожливо, тепер решта флоту Альянсу зможе нарешті кинути тут якір в мирі..."}
# {'title': 'Розірвана земля', 'objective': "Вбийте 3 щупальця Ізо'рата.", 'description': "Нас не доведеться довго вмовляти, щоб повернути проти Сутінкових — це вже наша мета. Ми вже воюємо тут, тож нам може знадобитися твоя допомога, перш ніж ми зможемо рушити до їхньої фортеці.\n\nСутінкові вже витягли Ізо'рата з-під землі на півдні, ти, мабуть, помітив. Його щупальця вириваються з-під землі навколо нас. Нам би не завадила допомога, якщо ти {стать:готовий:готова} допомогти.", 'progress': 'Тобі вдалося впоратися з тими щупальцями?', 'completion': 'Дякую, {клас:к}. Нам тепер буде легше дихати.'}
# {'title': 'Відбиття атаки', 'objective': 'Убийте 12 членів Сутінкового Молота в руїнах Дракґора.', 'description': 'Сутінковий Молот знищив поселення Драконової Пащі на півдні та проводить там свої ритуали. Не дай їм продовжити їхні заклинання. Віднеси бій до них!', 'progress': None, 'completion': 'Помста гірка, але я радий, що в нас є хтось такий {стать:могутній:могутня}, як ти, щоб довести це до кінця.'}
# {'title': 'Незламна', 'objective': 'Знайдіть гукачку землі Єву в руїнах Дракґора.', 'description': "Ми готуємо ритуал, який допоможе знищити Ізо'рата, породжену Старими Богами потвору, яку Сутінковий Молот витягнув з глибин. Але нам заважає те, що одну з наших найсильніших бійчинь захопили під час штурму їхнього табору.\n\nГукачка землі Єва знаходиться в руїнах на півдні. Вона жива. Я в цьому впевнена. Будь ласка, врятуй її. Якщо хтось з нас і заслуговує на твою допомогу, то це вона.", 'progress': None, 'completion': 'Дякувати стихіям, що ти {стать:прийшов:прийшла}. Тебе прислали мої побратими?'}
# {'title': 'Прості рішення', 'objective': 'Зберіть 10 бочок з маслом для багаття.', 'description': 'Я новачок у цій справі. Дуже новачок. Але знаєш що? Це дає мені перевагу!\n\nЦі мої друзяки-шамани натрапили на щось велике, але вони надто зациклені! Вони покладаються на стихії і забувають використовувати звичайні матеріали, що оточують їх.\n\nВ руїнах на півдні я бачив, як ці сутінкові головорізи тягли бочки з легкозаймистою олією! Вони використовували її, коли спалювали місто. Думаю, ми зможемо використати її, щоб спалити їх.', 'progress': 'Цікаво, що станеться, якщо облити елемента цією штукою. Вийде супер-великий-багаття-елемент? Думаю, так. Треба буде спробувати.', 'completion': 'Ось про що я говорив! Ти можеш уявити собі всі можливі варіанти використання цієї речовини? Я — ні. Але я можу уявити багато чого, і мені це подобається.'}
# {'title': "Милосердя до зв'язаних", 'objective': 'Зберіть 5 сердець плотепалів.', 'description': "Звісно, я не хотів залишатися тут, але для ритуалу потрібні були матеріали... Я затримався, щоб добути їх, і саме це призвело до мого полону.\n\nЯ повернуся до кола, але буду тобі дуже вдячний, якщо ти виконаєш те, що не зміг я. Нам потрібні серця зв'язаних вогняних елементалів, яких поневолив Сутінковий Молот в західній частині табору.\n\nЕлементалі вже втратили надію, але в цій жертві вони зможуть помститися.\n\nЗустрінемось в таборі.", 'progress': 'Ти {стать:дістав:дістала} серця?', 'completion': "Дякую, {ім'я:к}. Ти дуже {стать:здібний:здібна}. Я надзвичайно вдячний, що ти {стать:вирішив:вирішила} допомогти нам, а не {стать:пройшов:пройшла} повз, як інші шукачі пригод."}
# {'title': 'Наші хлопці на узбережжі', 'objective': 'Поговоріть з лейтенантом Емрі на Сутінковому узбережжі, що в Сутінковій верховині.', 'description': 'Ситуація у верховині змінюється щохвилини. Наша мета — штурм Бастіону Сутінків, але я не можу навіть забезпечити висадку на узбережжі, бо ця клята Орда постійно заважає.\n\nПоки я збираю рештки флотилії, мені потрібні люди, які будуть захищати берег.\n\nВирушай на узбережжя до лейтенанта Емрі та допоможи його морським піхотинцям відбити атаку Орди!', 'progress': None, 'completion': 'Пригни голову, якщо не хочеш її втратити, {клас:к}!\n\nЦе МІЙ пляж.\n\nОрда ХОЧЕ мій пляж.\n\nВони НЕ ОТРИМАЮТЬ мій пляж.\n\nТепер ситуація з пляжем зрозуміла?'}
# {'title': 'Розвідка узбережжя', 'objective': 'Розвідайте контрольну точку на Сутінковому узбережжі. Вам не потрібно її захоплювати, але якщо ви це зробите, ваша сторона отримає бойову перевагу, а ви будете помічені для PvP.', 'description': "Або вони, або ми, {клас:к}. Хтось один буде командувати на цьому пляжі.\n\nНа північ звідси ти побачиш невеликий пагорб, з якого відкривається вид на все узбережжя. Хто контролює цей пагорб, той має перевагу на всьому узбережжі!\n\nМені потрібно знати, яка там зараз ситуація. Розвідай контрольну точку на пляжі, позначену величезним прапором, а потім повертайся до мене.\n\nТобі не обов'язково намагатися захопити її, якщо тільки ти не жадаєш бою...", 'progress': "Які там новини, {ім'я:к}?", 'completion': 'Ось такі справи, солдате. Якщо тобі важко битися тут, на узбережжі, можеш допомогти нам захопити та утримати той пагорб.'}
# {'title': 'Захоплення території', 'objective': 'Вбийте 12 піхотинців з загону "Сокирозуб" на Сутінковому узбережжі в Сутінковій верховині.', 'description': 'Ординський загін "Сокирозуб" отаборився на моєму прекрасному пляжі.\n\n<Лейтенант вказує на північ, вздовж берега.>\n\nПовбивай їх.', 'progress': "Ти ще {стать:живий:жива}, {ім'я:к}.\n\nА вони?", 'completion': 'Мертві? І не один десяток?\n\nЦе лише початок, {клас:к}. Початок.'}
# {'title': 'Паща Божевілля', 'objective': 'Поговоріть з гукачем землі Торунскаром в Колі Стихій.', 'description': 'Не можу в це повірити, {ім\'я:к}. Мій власний син — моя плоть і кров! Він пов\'язав свою долю з тими покидьками з Сутінкового Молота. Ти {стать:бачив:бачила}, на що він перетворився, коли намагався зірвати весілля? Ох... Чому? Чому?\n\nЦе все через ту тварюку, {ім\'я:к}. Величезну пащу, що з\'явилася із землі на заході. "Паща Божевілля!" Мій син казав, що вона говорила з ним, але я думав, що йому це просто наснилося.\n\nСлужителі Землі намагаються знищити її. Іди до гукача землі Торунскара, він на заході звідси, і дізнайся, чим ти можеш допомогти!', 'progress': None, 'completion': 'Ласкаво просимо, сестро. Ти {стать:прийшла:прийшов} до нас у важкий час, але нам пощастило. Нам би не завадила твоя допомога.'}
# {'title': 'Плач рани', 'objective': 'Поговоріть з гукачем землі Торунскаром в Колі Стихій.', 'description': "Звір, {ім'я:к}! Я побачив звіра. Велика паща, ще більший голод. Вони не усвідомлюють, що випустили на волю.\n\nВін тут. Його жахливе безформне тіло виривається прямо в Нагір'я.\n\nЯ бачив тебе у своєму видінні, {ім'я:к}. Ти будеш боротися зі Служителями Землі, щоб зупинити звіра. Ти зустрінешся з пітьмою.\n\nІди зараз, поки звір не набрався сил. Поговори з гукачем землі Торунскаром в Колі Стихій, на північному заході, на хребті за зруйнованим табором Дракгор. Поспішай!", 'progress': None, 'completion': 'Ласкаво просимо, {стать:брате:сестро}. Ти {стать:прийшов:прийшла} до нас у важкий час, але нам це на руку. Нам не завадить твоя допомога.'}
# {'title': "Паща Ізо'рата", 'objective': "Сядьте на грифона, щоб взяти участь в атаці на Ізо'рата.", 'description': "Ми готові атакувати звіра. Спочатку нам потрібно знищити його щупальця, потім Єва проведе ритуал, щоб викликати могутнього вогняного елементаля, якого ми скинемо в пащу Ізо'рата.\n\nЯ хочу, щоб ти {стать:вилетів:вилетіла} з нашою першою групою. Тримайся, поки не з'явиться можливість, а потім приєднайся до інших шаманів у бою зі щупальцями.\n\nСідай на будь-якого грифона, коли будеш готов{стать:ий:а} приєднатися до штурму.", 'progress': 'Ми мали зустрітися біля грифонів. Дотримуйся плану.', 'completion': 'Щупальця збили з грифонів і нас! Вони були набагато спритніші, ніж ми очікували.\n\nНеважливо. Ми були готові до такого. Я можу викликати елементаля звідси, якщо ти зможеш мене захистити.'}
# {'title': 'Проковтнуті', 'objective': "Захистіть себе та Єву, гукача землі, від захисних механізмів Ізо'рата.", 'description': "Ми знали, що таке можливо, але ми не уявляли, як звір буде захищатися. Тіло Ізо'рата швидко реагує на нашу загрозу.\n\nЯ можу завершити призов звідси, але тільки якщо ти зможеш стримати захисні механізми Ізо'рата. Не дай їм дістатися до нас! Ми виживемо!", 'progress': None, 'completion': 'Я врятувала тебе від смерті, герою!\n\nСмертекрил близько! Нам потрібна твоя допомога.'}
# {'title': 'Смертекрил', 'objective': 'Переможіть Смертекрила, Аспекта Смерті.', 'description': "Немає часу! Смертекрил вдарив раніше, ніж ми змогли об'єднатися проти нього. Якщо ти не зупиниш його, Служителі Землі не доживуть до кінця цього дня!", 'progress': None, 'completion': 'Ти {стать:прокинувся:прокинулась}! Дякувати стихіям. Я майже втратив усю надію.'}
# {'title': "Жахи Ізо'рата", 'objective': "Врятуйте Харґота Тьмяноспалаха, Землекрушителя Дуана, Покликачку бурі Джалару та Покликачку бурі Мілру.\n\nПоверніться до інших шаманів, якщо шлунковий сік Ізо'рата почне роз'їдати вас.", 'description': "Ти нам потрібен! Ти {стать:застряг:застрягла} в якомусь кошмарі. Багато інших шаманів теж.\n\nЦе не важливо... наш план руйнується. Дехто з наших шаманів створює захисні аури, які протистоять шлунковому соку та не дають нам загинути, але нам потрібно, щоб ти {стать:врятував:врятувала} інших шаманів від щупалець. Ми не зможемо перемогти Ізо'рата без них!\n\nНе залишайся в шлунку без інших шаманів надто довго, інакше тебе переварять живцем!", 'progress': "Битва ще не закінчена. Шамани, що опинилися в Ізо'раті, потребують твоєї допомоги!", 'completion': "Об'єднавшись зі Служителями Землі, ми зможемо пережити жахи Ізо'рата. Тепер настав час помститися йому!"}
# {'title': 'Кошмар', 'objective': "Знищте мозок Ізо'рата.", 'description': "Мозок Ізо'рата відкрився! Шаман, якого ви врятували, допоможе вам пробитися крізь його захист.\n\nВдарте по мозку та знищте Ізо'рата!", 'progress': ' ', 'completion': "Сьогодні ти {стать:врятував:врятувала} багатьох моїх союзників, {ім'я:к}. Можу лише уявити, які жахіття ти {стать:бачив:бачила} всередині Ізо'рата, але вся спільнота Служителів Землі вдячна тобі."}
# {'title': 'Розбирання дереворубів', 'objective': 'Знищте алмазно-лезові дереворуби та зберіть 5 пошкоджених частин дереворуба.', 'description': 'Наші танки відступають, а це означає, що їх доведеться ремонтувати в польових умовах.\n\nРозтрощ кілька алмазно-лезових дереворубів, якими ті зелені монстри рубають дерева вздовж узбережжя, та принеси мені купу уламків. Ми змайструємо щось, щоб знову завести наші танки.', 'progress': "Що ти мені {стать:приніс:принесла}, {ім'я:к}?", 'completion': "О, так, це те, що треба! Хороший інженер може зробити все з чого завгодно.\n\nЦя штуковина може з'єднати зламаний циліндр... О! А хто не хоче мати додаткову деталь? ...А з цього можна зробити... річ.\n\n<Кремезклок засовує одну з вимазаних в мастилі деталей двигуна в рот.>\n\nТак, ідеально."}
# {'title': 'Порятунок облогової машини', 'objective': 'Поговоріть з командиром облогової машини, що стоїть на ній, після чого захистіть її, поки інженери проводять ремонт.', 'description': 'Нам доведеться витягти наші облогові машини з багнюки, одну за одною. Візьми ці запасні частини, які ти {стать:зібрав:зібрала}, і віддай командиру облогової машини, що стоїть на своїй пошкодженій техніці.\n\nА потім захищай машину, поки інженери будуть її лагодити.\n\nЙди та зроби мене {стать:гордим:гордою}, {клас:к}!', 'progress': 'Каміння, пеньки, пагорби, багнюка... Ха.\n\nНенавиджу природу.', 'completion': "Так, ще одна машина прямує додому на ремонт.\n\nЦі дерева, пеньки, багнюка, каміння — сюди навіть м'яч для гольфу не загнати, не те що танк.\n\nПотрібен новий підхід."}
# {'title': 'Теплий прийом', 'objective': 'Зустріньтеся з Лірастразою в Цинобровому бастіоні.', 'description': 'Рада, що ти {стать:повернувся:повернулася}! Напевно, знову {стать:рятував:рятувала} світ.\n\nМене відправили налагодити відносини з червоними драконами, але ця група не така гостинна, як ті, що в Храмі Драконячого Спочину. Однак, мені сказали, що ти вмієш вирішувати проблеми.\n\nА точніше, {стать:вирішувати:вирішувати} проблеми.\n\nМоже, спробуєш заслужити довіру Лірастрази з Цинобрового бастіону, що на південному заході? Було б чудово, якби ти {стать:умовив:умовила} її трохи піти мені назустріч.', 'progress': 'Вірю, що Ліра хотіла з тобою поговорити.', 'completion': 'Рада, що Ліра тебе не злякала. Не можу сказати, що її побоювання безпідставні, але в нас спільний ворог. Вона просто трохи надто завзята.'}
# {'title': 'Теплий прийом', 'objective': 'Зустріньтеся з Лірастразою в Цинобровому бастіоні.', 'description': "Добре. Ти {стать:повернувся:повернулася}. Гадаю, знову рятуєш світ.\n\nМене відправили налагодити відносини з червоними драконами в цьому районі, але ця група виявилася не такою привітною, як ті, що в Храмі Драконячого Спокою. Однак, мені сказали, що ти {стать:такий:така}, хто вміє розв'язувати проблеми.\n\n{стать:Розв'язувач:Розв'язувачка} проблем, так би мовити.\n\nТобі потрібно завоювати довіру Лірастрази в Цинобровому бастіоні, що на південному заході. Наш зв'язок з Драконовою Пащою ускладнив справи, але я сподіваюся, що ти зможеш налагодити відносини.", 'progress': 'Здається, Ліра хотіла з тобою поговорити.', 'completion': 'Радий, що Ліра тебе не злякала. Не буду казати, що її побоювання не обґрунтовані, але у нас спільний ворог. Можливо, вона просто трохи надто завзята.'}
# {'title': 'Висадка ШУР', 'objective': 'Отримайте загін пекельників Громового Молота від Ангуса Нерухомої Гори, а потім доставте їх до точки висадки біля Сутінкової брами.', 'description': "Матіас Гич та ШУР тут, щоб допомогти нам у операції в Сутінковій цитаделі. Ти {стать:супроводиш:супроводиш} їх туди.\n\nГромовий Молот люб'язно погодився доставити нас туди. Але спочатку агентам потрібно виконати деякі справи біля Сутінкової брами.\n\nПоговори з Ангусом Нерухомою Горою та попроси в нього загін для висадки. Ти {стать:доставиш:доставиш} їх туди. Місце позначено великою синьою літерою Х.", 'progress': "Ти {стать:повинен:повинна} безпечно доставити агентів ШУР до місця призначення, {ім'я:к}.", 'completion': 'Це було смертельно небезпечно.\n\nХоч я і не схвалюю їхніх методів, але ніхто не може поставити під сумнів ефективність майстра Матіаса Гича та його ШУР. Не кажучи вже про те, що ти тут. Наша перемога практично забезпечена.'}
# {'title': "Висадка Кор'крону", 'objective': 'Отримайте загін вершників на вітрах Розгромару від Джон-Джона Желейної Шиї, а потім відведіть їх до точки висадки в Сутінковій брамі.', 'description': "Ґарона та загін Кор'крону тут, щоб допомогти нам з операцією в Сутінковій цитаделі. Ти маєш супроводити їх туди.\n\nЯ звернувся до місцевого племені тролів, щоб вони відвезли нас на своїх вершниках на вітрах. Але душогубам потрібно спочатку зробити дещо в районі Сутінкової брами.\n\nПоговори з вождем тролів, Джон-Джоном Желейною Шиєю, та отримай загін Кор'крону для висадки. Ти їх туди доставиш. Місце позначено великою червоною літерою X.", 'progress': "Ти маєш безпечно доставити тих душогубів Кор'крону до місця призначення, {ім'я:к}.", 'completion': "Це, мабуть, було захопливо.\n\nНезважаючи на втрати, яких міг зазнати Кор'крон в дорозі, ніхто не зможе сумніватися в їхній ефективності, як і в ефективності Ґарони. А з тобою в команді — перемога лише питання часу."}
# {'title': 'Огри та еттіни', 'objective': 'Убийте 10 огрів або еттінів біля Сутінкової брами.', 'description': 'Як і в будь-якому наступі, спочатку потрібно їх послабити. Ми вже чортзна-скільки намагаємося туди пробитися. Але хтось такий, як ти... Ну, скажімо так, я не сумніваюся, що ти зможеш пробратися до Сутінкової брами, що на південному заході, і провчити огрів та еттінів клану Кривавого Ока!', 'progress': 'Що таке? У хлопців з Альянсу кишка тонка, щоб виконати роботу?\n\n<Курдран підморгує вам.>\n\nМені пролетіти туди та вбити їх за тебе?', 'completion': 'Оце я розумію, хлопче! Схоже, що сьогодні буде хороший день.'}
# {'title': 'Огри та еттіни', 'objective': 'Вбийте 10 огрів або еттінів клану Кривавого Ока біля Сутінкової брами.', 'description': "Я хочу, щоб ти {стать:пробрався:пробралась} за ті валуни на північний захід, до Сутінкової брами. Вбий усіх огрів та еттінів клану Кривавого Ока, яких побачиш. Думаєш, {ім'я:к}, ти з цим впораєшся?", 'progress': 'Там є ще кого вбивати, {раса:к}. У тебе вистачить мужності на це, так?', 'completion': 'А я думав, що сьогоднішній день не може бути кращим.\n\nПриємно іноді помилятися.'}
# {'title': 'Зрушити гору', 'objective': 'Підірвіть приховану вибухівку, щоб виманити Череподробника-Гору від Сутінкової брами.', 'description': "Щоб зруйнувати Сутінкову браму, нам потрібно виманити Череподробника-Гору звідти!\n\nПеред від'їздом я подбав про те, щоб твої агенти ШУРу взяли вибухівку, сховану в ящику Сутінкового Молота. До цього часу вони вже мали б встановити її на сходах, що ведуть до верхньої частини цитаделі.\n\nТи маєш підірвати вибухівку, а потім дати нам сигнал, коли монстр відійде.\n\nТоді ми нападемо і знищимо укріплення огрів!", 'progress': None, 'completion': None}
# {'title': 'Зрушити гору', 'objective': 'Підірвіть сховані вибухівки, щоб відволікти Череполама Гору від Сутінкової брами.', 'description': "Якщо ми хочемо знищити Сутінкову браму, нам потрібно витягти звідти Череполама Гору!\n\nПеред відходом я прослідкував, щоб твої кор'кронські душогуби взяли вибухівку, сховану в ящику Сутінкового Молота. Зараз вони мають встановити її на сходах, що ведуть до верхньої частини цитаделі.\n\nТи маєш підірвати вибухівку та дати нам сигнал, коли монстр буде знищений.\n\nТоді ми нападемо та знищимо всю базу огрів!", 'progress': None, 'completion': None}
# {'title': 'Виклик артилерії', 'objective': 'Використайте артилерійську сигнальну ракету, щоб навести гармати на північну, північно-східну, південно-західну та південну будівлі Сутінкової брами.', 'description': 'Я віддаю перевагу чесному бою. Ці монстри заслуговують лише на те, щоб їх знищили нашою зброєю. Однак у цій ситуації потрібно використовувати більш потужні засоби.\n\nВізьми цю сигнальну ракету та познач нею чотири будівлі Сутінкової брами, що на південному заході. Решту зроблять наші гармати.', 'progress': 'Дякуючи тобі, наші гармаші влучили у цілі. Розкажи, що там всередині Сутінкової брами.'}
# {'title': 'Виклик артилерії', 'objective': 'Позначте артилерійською сигнальною ракетою північну, північно-східну, південно-західну та південну будівлі Сутінкової брами.', 'description': 'Шкода, що нам більше не дозволяють скидати Чуму на ворогів. Вона була б дуже ефективною в цій ситуації. Ну, принаймні, у нас є бойові машини, щоб знищити їхню дорогоцінну браму.\n\nВізьми цю сигнальну ракету. Познач нею чотири будівлі Сутінкової брами, що на північному заході. А бойові машини зроблять все інше.', 'progress': None, 'completion': 'Мушу сказати, мені сподобалося, як руйнуються їхні будівлі.'}
# {'title': 'Сигнал до атаки', 'objective': 'Подайте сигнал до атаки з вершини однієї з веж Сутінкової брами.', 'description': 'Тепер, коли ви відволікли Череполама з Сутінкової брами, настав час подати сигнал до атаки для ваших сил в таборі Переможця!', 'progress': None, 'completion': None}
# {'title': 'Сигнал до атаки', 'objective': 'Подайте сигнал до атаки з однієї з веж Сутінкової брами.', 'description': 'Тепер, коли ви відволікли Череподера з Сутінкової брами, настав час подати сигнал військам Розгромару до атаки!', 'progress': None, 'completion': None}
# {'title': 'Чотири голови краще, ніж жодної', 'objective': "Добудьте чотири голови За'брокса та Бібл'фода.", 'description': "Поки триває атака на Сутінкову браму, залишилось ще одне незавершене діло: За'брокс та Бібл'фод, учні Чо'Галла.\n\nЗа даними розвідки, вони перебувають у лігві Послідовників, невеликій печері огрів у південно-західному куті Сутінкової брами.\n\nВи впевнені, що Кассій та Курдран захочуть побачити докази їхньої смерті.", 'progress': 'Це з твоєї сумки капає кров?', 'completion': '<Паладин хмуриться.>\n\nУ тебе досить моторошна колекція трофеїв. Я б тобі повірив, якби ти просто {стать:сказав:сказала}, що вони мертві. У будь-якому разі, дякую, що {стать:подбав:подбала} про них.\n\nСутінкова брама скоро буде нашою. Час рухатись до Сутінкової цитаделі.'}
# {'title': 'Чотири голови краще, ніж жодної', 'objective': "Добудьте чотири голови За'брокса і Бібл'фода.", 'description': "Тепер, коли почався наступ на Сутінкову браму, залишилося розв'язати останню проблему: За'брокс і Бібл'фод, учні Чо'Галла.\n\nЗа даними розвідки, вони знаходяться в лігві Послідовників, невеликій печері огрів у південно-західному куті Сутінкової брами.\n\nВи впевнені, що леді Козвін і Заела захочуть отримати докази їхньої смерті.", 'progress': 'Це кров капає з твоєї сумки? Сподіваюся, це не твоя.', 'completion': '<Знатна леді зловісно посміхається.>\n\nУ тебе досить жахлива колекція трофеїв. Я б тобі повірила, якби ти просто {стать:сказав:сказала}, що вони мертві, але я ціную твої зусилля. Дякую, що {стать:потурбувався:потурбувалася} про них.\n\nСутінкова брама скоро буде нашою. Час просуватися до Сутінкової цитаделі.'}
# {'title': 'До цитаделі', 'objective': 'Поговоріть з командиром загону ШУР, а потім супроводжуйте загін.', 'description': "Тепер, коли атака розпочалася, настав час зайнятися Сутінковою цитаделлю. Якщо ти не проти, я б хотів, щоб ти {стать:супроводив:супроводила} війська ШУР до майстра Матіаса Гича.\n\nВін ховається десь нагорі. Командир загону ШУР скаже тобі, де саме.\n\nДякую, {ім'я:к}. Ми з нетерпінням чекаємо на зустріч з тобою під час штурму цитаделі!", 'progress': None, 'completion': None}
# {'title': 'До цитаделі', 'objective': "Поговоріть з командиром загону Кор'крона, а потім проведіть загін Кор'крона.", 'description': "Тепер, коли розпочався наступ, настав час розібратися з Сутінковою цитаделлю. Якщо ти не проти, я б хотіла, щоб ти {стать:провів:провела} сили Кор'крона до Ґарони.\n\nВона ховається десь нагорі. Командир загону Кор'крона скаже тобі, де саме.\n\nДякую, {ім'я:к}. Ми з нетерпінням чекаємо на тебе, щоб разом штурмувати цитадель!", 'progress': None, 'completion': None}
# {'title': "Навіть дракони можуть стікати кров'ю", 'objective': 'Поговоріть з Веластразою в Цинобровому бастіоні.', 'description': "Я не настільки неввічлива, щоб відмовлятись від допомоги, якщо ти її пропонуєш.\n\nМи постійно б'ємося з присмерковими драконами та дракончиками на півдні. Наші удари не були безуспішними, але дракони, що виходять з Ґрім-Батола, дихають на нас якоюсь скверною, яку нелегко очистити.\n\nВеластраза та Злошквар піклуються про наших поранених побратимів. Іди та подивися, чи зможеш ти їм чимось допомогти.", 'progress': None, 'completion': 'Кален став дуже довірливим. Рідко коли стороннім дозволяють заходити в бастіон.'}
# {'title': 'Драконяче зцілення', 'objective': 'Захистіть 5 малинових цілителів, поки вони лікують поранених драконів.', 'description': 'Наші дракони повертаються з бою, вкриті вогнем Сутінкового Молота та переслідувані сутінковими дракончиками.\n\nМої цілителі можуть подбати про рани наших драконів, але їх треба захистити. Відганяй дракончиків від моїх цілителів. І якщо можеш, допоможи зцілити наших драконів.\n\nДякую за допомогу. Бої за Ґрім-Батол не припиняються. Нам потрібно якомога швидше повернути наших найсильніших драконів у бій.', 'progress': 'Захищай цілителів, поки вони зцілюють наших поранених драконів!', 'completion': 'Ми відберемо Ґрім-Батол у Сутінкового Молота та їхніх союзників. Це може зайняти деякий час, але ми не можемо відступити.'}
# {'title': 'Життя після смерті', 'objective': 'Посадіть рубінове насіння на трупах 6 драконів з Цинобрового бастіону.', 'description': "{Раса:к}, у мене є завдання для тебе.\n\nВізьми це рубінове насіння та посади його на трупах драконів, яких ти зустрінеш. Присмеркових чи Цинобрових, дитинчат чи дорослих, не важливо. Ми повинні переконатися, що їхні тіла повернулися до землі, щоб життя продовжувало процвітати.\n\nПісля смерті завжди має з'являтися нове життя. Це може бути нашою єдиною втіхою в часи війни та великої трагедії.", 'progress': 'Ти {стать:зробив:зробила} те, про що я просив?', 'completion': 'Таким чином ми не даємо Смертекрилу знищити те, що він так пристрасно прагне знищити. І завдяки цьому життя триває.'}
# {'title': 'Наступ Сутінкових', 'objective': 'Вбийте 12 сутінкових загарбників в Цинобровому бастіоні.', 'description': 'Крихкі сутінкові загарбники заполонили бастіон. Вони лізуть звідкись з заходу.\n\nУ цьому священному місці для них не буде пощади. Виплесни на них всю свою лють.', 'progress': None, 'completion': 'Бачу, в тебе є талант до вбивства. В наші часи це цінується.'}
# {'title': 'Далеко від гнізда', 'objective': 'Здобудьте 6 яєць багряних драконів.', 'description': 'Послухай... Я знаю, що тобі немає за що мене любити, так само, як і мені тебе, але мені потрібна будь-яка допомога.\n\nНаші яйця крадуть ці Сутінкові загарбники. Я не сумніваюся, що вони хочуть відвезти їх назад до Ґрім-Батолу, щоб експериментувати над ними і спотворити. Я не дозволю цьому статися.\n\nЯкщо ти дійсно хочеш допомогти нам, зупини їх! Поверни яйця. Принеси їх мені.', 'progress': 'Сутінкові дракони народилися внаслідок цих огидних експериментів. Сутінковий Молот зайшов надто далеко. Смертекрил зайшов надто далеко.', 'completion': 'Я не знаю, чи зробив ти це заради мене, чи заради малюків, що всередині цих яєць, але це не має значення, в будь-якому випадку, ти хочеш бути {стать:союзником:союзницею} нашого виводка. Я ціную це.\n\nЯ не можу пробачити твоїх союзників, які нападали на моє потомство, але, здається, ти {стать:обрав:обрала} правильну сторону.'}
# {'title': 'Пролом в обороні', 'objective': 'Знайдіть та знищте джерело Сутінкового Молота в Цинобровому бастіоні.', 'description': 'Кожен клаптик повітря та кожен пагорб навколо бастіону постійно перебуває під пильним наглядом драконів Ліри. Вони, мабуть, знайшли шлях до святилища знизу.\n\nВізьми цю порошинку Спалаху. Її має вистачити, щоб закрити будь-яку діру, тунель чи портал, яким вони могли скористатися, щоб потрапити всередину.\n\nЗнайди пролом в обороні та закрий його.', 'progress': None, 'completion': 'Чудова робота. Дякую, {раса:к}.\n\nЯ не буду настільки дурною, щоб допустити таку помилку знову.'}
# {'title': 'Птах збитий!', 'objective': 'Знайдіть Тордена Молотобоя, збитого вершника на грифонах з клану Диких Молотів, на Сутінковому узбережжі, що в Сутінковій верховині.', 'description': 'Поки ти {стать:бився:билася} на узбережжі, я помітив, як грифон випав з хмар майже на захід звідси.\n\nЦе був не наш.\n\nМабуть, він належав комусь з Диких Молотів. Я знаю, що Курдран хотів встановити контакт з кланами Диких Молотів після захоплення пляжу.\n\nЯ не можу посилати своїх людей на пошуки, але можу послати тебе. Знайди того збитого грифона з клану Диких Молотів!', 'progress': None, 'completion': 'О, чорт забирай. Ти просто {стать:солдат:солдатка} Альянсу. А я сподівався на порятунок.'}
# {'title': 'Коріння допоможе', 'objective': 'Зберіть 8 колючих смердокоренів на Сутінковому узбережжі.', 'description': "Поглянь, друже. Вона вже ледве тримається! Якщо моя пташка помре, я буду ні на що не здатний.\n\nТож допоможи. Тут, на півострові, можна викопати колючі смердокорені. О, цей запах зіб'є тебе з ніг, але якщо відварити їх у воді, вийде потужні ліки.\n\nПринеси трохи, поки я захищаю свою пташку. І поквапся! В Альянсі ж не славляться своєчасним втручанням, чи не так?", 'progress': 'Ти {стать:приніс:принесла} мені коріння, {клас:к}? Ну?', 'completion': 'О, це те, що треба! Сподіваюсь, ти його не куштував. Воно викликає жахливі спазми, але для птахів — це чудодійні ліки.'}
# {'title': 'Повернення на Високий берег', 'objective': 'Поговоріть з Тордуном Молотобоєм і полетіть разом з ним на Високий берег.', 'description': 'Ага, дивись! Мені здається, вона вже оклигує.\n\nНу, {стать:містер:міс} {стать:синьобронник:синьобронниця} {клас:н}. Це твоя база на березі? Високий берег, кажеш? Чи зможемо ми з моїм птахом там оселитися, поки вона не одужає?\n\nСтрибай! Ми разом полетимо на Високий берег!', 'progress': "Які новини з півострова, {ім'я:к}?", 'completion': "Гарна робота, {ім'я:к}! Допомога тому збитому грифоннику стала нашим першим контактом зі старими кланами Диких Молотів. Ми зможемо дізнатися, хто ще залишився і в якій кількості.\n\nНаш похід просувається!"}
# {'title': 'Відкриття порталу', 'objective': 'Убийте забруднених водяних елементалів та зберіть 5 ядер водоверті.', 'description': 'Наші друзі зі Служителів Землі намагаються відкрити портали назад до Штормовію, але поки безуспішно. Та ось Тордун каже, що в нього є ключ.\n\nНавіжені водяні елементалі в дельті річки Веррал збожеволіли. Тордун каже, що ми можемо спрямувати їхню енергію у портал.\n\nЯ не розумію всі ці елементальні нісенітниці, але розумію одне: вбиваєш елементалів та забираєш їхні ядра водоверті. Достав їх Талі у двір!', 'progress': 'Привіт, {клас:к}. Курдран каже, що ти знаєш, як відкрити портал?', 'completion': "Отакої, {ім'я:к}. Ці елементальні енергії такі потужні, такі хаотичні... Не дивно, що Сутінковий Молот вирішив побудувати тут свою фортецю!\n\nЯ повинна спробувати спрямувати ці енергії у щось більш нешкідливе та продуктивне. Спробуємо..."}
# {'title': 'Ідеальна примочка', 'objective': 'Зберіть 10 куп річкового мулу Веррала.', 'description': "Ти не хочеш прогулятися дельтою річки Веррал? У мене є одна порада, яка допоможе твоїм друзям... і моєму пташеняті!\n\nКоли водяні елементалі прокладають собі шлях крізь скелі, вони створюють особливий вид мулу. Він твердне, як камінь, але несе в собі цілющу силу води. Якщо зробити пов'язку з цього мулу, зламані кістки зростуться, як залізо.\n\nПринеси трохи цього мулу Талі, вашій шаманці, що сидить внизу. Вона знатиме, що з ним робити!", 'progress': 'Що це я чую про мул річки Веррал?', 'completion': 'О... Бруд. Ти принесла мені бруд?\n\nВау, він просто переповнений силою! Тепер я розумію, про що говорив Тордун. Я роздам його всім цілителям. Наші поранені швидко стануть на ноги!'}
# {'title': 'Шлях відкрито', 'objective': 'Поговоріть з Курдраном Диким Молотом у Високому березі, що на Сутінковій верховині.', 'description': 'Ми з моїм колегою-шаманом залишимось тут, щоб підтримувати портал відкритим.\n\nА ти підійди нагору та повідом Курдрану, що роботу виконано. Він буде радий почути хоч якісь хороші новини.', 'progress': None, 'completion': "Го! Я знав, що ти {стать:клас, на якого можна покластися:клас, на яку можна покластися}, {ім'я:к}. Користуйся порталом, коли потрібно буде повернутися зі Штормовію на верховину.\n\nА тепер, час повертатися до справ. Нам потрібно відшукати та об'єднати клан Диких Молотів, розкиданий по всій верховині. Поговори з Тордруном, це буде гарним початком!"}
# {'title': 'Захист бастіону', 'objective': 'Поговоріть з Каленном у Цинобровому бастіоні.', 'description': 'Каллен передав звістку — Сутінковий Молот пробрався в бастіон!\n\nЯкщо ти хочеш заслужити його довіру, то кращого моменту не знайти!', 'progress': ' ', 'completion': 'Сподіваюсь, ти {стать:такий же міцний:така ж міцна}, як і твоє спорядження. Сутінковому Молоту якось вдалося пробратися в бастіон і мені потрібен хтось, хто вистежить їх.'}
# {'title': 'Командування Латки', 'objective': 'Поговоріть з Латкою в проході Драконової Пащі.', 'description': 'Останні події доводять, що засісти тут і час від часу нападати на ворога недостатньо, щоб захистити наш рід, не кажучи вже про повернення Ґрім-Батола. Нам потрібно бути агресивнішими, потрібно вдарити в саме серце ворога.\n\nЯ погодився відправити драконів на допомогу твоїм командирам. Вони вже виношували план атаки на Ґрім-Батол, тож тобі варто зосередитися на цьому.\n\nТи зможеш знайти Латку в проході Драконової Пащі, в каньйоні під нами, на півдні.', 'progress': None, 'completion': "Ти {стать:залучив:залучила} драконів до справи! Молодець.\n\nДо того часу, як дракони зв'язалися з нами, ми вже розробили план засідки. Вони допомагають, відрізаючи ворогові шляхи відступу.\n\nАле ти ще встигнеш взяти участь в битві. Ми дещо приберегли для тебе."}
# {'title': 'Північний фланг', 'objective': 'Поговоріть з Гралоком в Слизькій бухті, що в Сутінковій верховині.', 'description': 'Я наказала встановити оборонний периметр на північному узбережжі, в Слизькій бухті. Наші розвідники повідомили, що наги намагаються висадитися там.\n\nГралок керує операцією. Поговори з ним і допоможи захистити пляж!', 'progress': None, 'completion': 'Тебе прислала воєвода Заела? Добре.\n\nЯкщо Орда настільки сильна, як обіцяв ваш воєвождь, то я сподіваюсь, що на цьому березі проллється чимало крові.'}
# {'title': 'Кров на хвилях', 'objective': 'Убийте 15 нападників або повелительок з Чорної Луски.', 'description': "Ці нагові покидьки думають, що зможуть піднятися вгору по річці, щоб підкріпити Бастіон Сутінків. Ми ВІДІРВЕМО їм риб'ячі голови і ВИРВЕМО їхні ХРЕБТИ.\n\n<Гралок вганяє свій палаш у землю.>\n\nЗнищ Чорну Луску!", 'progress': None, 'completion': "<Гралок оцінює вас.>\n\nТи {стать:справжній:справжня} боєць, {ім'я:к}. Мені сподобалось спостерігати за тобою. Можливо, Драконова Паща справді заслуговує бути в твоїй Орді."}
# {'title': 'Снаряди на березі моря', 'objective': 'Зберіть 8 нерозірваних мінометних снарядів на пляжі Слизької бухти.', 'description': 'Я врятував ці міномети з уламків нашого дирижабля, коли він вибухнув над портом Драконової Пащі. Але боєприпасів не вистачає!\n\nПоки ти бігатимеш по пляжу, зроби мені послугу — підбери всі нерозірвані мінометні снаряди, які знайдеш.\n\nНерозірвані снаряди — найкращі, ніколи не знаєш, КОЛИ вони вибухнуть. Ідеально підходять для несподіванки ворога!', 'progress': 'У тебе є снаряди? Дай їх сюди!\n\n...Обережно!', 'completion': 'О, так. ТАК! Цими снарядами точно хтось загине.\n\nМабуть, наги.'}
# {'title': 'Сигнал до атаки', 'objective': 'Подайте сигнал до атаки з вершини однієї з веж Сутінкової брами.', 'description': 'Тепер, коли ти {стать:відволік:відволікла} Череподера Гірського від Сутінкової брами, нам потрібно, щоб ти {стать:подав:подала} сигнал нашим військам до атаки!', 'progress': None, 'completion': None}
# {'title': 'Сигнал атаки', 'objective': 'Подайте сигнал атаки з вершини однієї з веж Сутінкової брами.', 'description': 'Тепер, коли ти {стать:відволік:відволікла} Гірського Череподера від Сутінкової брами, мені потрібно, щоб ти {стать:подав:подала} сигнал до атаки нашим військам!', 'progress': None, 'completion': None}
# ...
# {'title': 'Знести стіну', 'objective': 'Вбийте 80 стрільців з Високого берега, 12 канонірів з Високого берега та 4 гармати з Високого берега за допомогою турелі «Неборіза».', 'description': 'Ти {стать:хлопець:дівчина}, що любить екшен. Сідай на одну з тих турелей і знищ їхню оборону на стіні.\n\nТільки швидше, гаразд? Бажано до того, як ми перетворимося на вогняну кулю.', 'progress': None, 'completion': 'Чудо модернізованої гоблінської руйнівної техніки, еге ж? Я просто обожнюю ці штучки.'}
# {'title': 'Прощальні подарунки', 'objective': 'Встановіть бомби на човні, біля входу в фортецю та в одній з північних веж.', 'description': 'Я впевнений, що Латка має якийсь грандіозний план, але це був би не штурм, якби ми не залишили після себе кілька вибухових подарунків.\n\nСпустися туди та встанови кілька цих вибухівок на човні, біля входу в фортецю та в одній з північних веж. Цього має бути достатньо, щоб підірвати їх.\n\nМи теж спускаємося на землю. Зустрінемось в східній вежі, коли закінчиш.', 'progress': None, 'completion': "Ха-ха-ха! Чудова вистава.\n\nЦе буде гідним вітанням для нагір'я."}
# {'title': 'Надзвичайно важливо', 'objective': 'Добудьте індукційний самофланж.', 'description': 'Коли дирижабль Гарроша впав, разом з ним зник і індукційний самофланж, який ти {стать:дістав:дістала} для нас в Азшарі. Альянс десь заховав його в цій фортеці, а Краз хоче повернути його.\n\nЯ думаю, що він в підвалі фортеці, тому почни пошуки там. Як тільки знайдеш його, принеси мені до східної вежі.', 'progress': 'Краз чекає. Продовжуй працювати.', 'completion': 'Чудово! Краз буде дуже радий, що ти {стать:повернув:повернула} самофланж додому. Молодець.'}
# {'title': 'Високий берег, мокрий берег', 'objective': 'Убийте 10 захисників Високого берега.', 'description': 'Спустись туди та розберись з тим Альянсівським збродом. Будь-хто з них підійде. Я просто хочу, щоб вони розбіглись, поки ти будеш там, після справжньої цілі.\n\nКоли закінчиш, знайди нас біля східної вежі.', 'progress': 'Будь ласка, ще трохи. Судячи з усього, їм нас ще недостатньо.', 'completion': 'Ось так це і робиться. Розвіяні за вітром. Не зовсім та бойова сила, якою вони себе вихваляють, еге ж?'}
# {'title': 'Варіятівка працює!', 'objective': 'Поговоріть з Ньют, щоб повернутися у Варіятівку, а потім віддайте капітану Варіяту самофланж.', 'description': 'Все, ми закінчили. Відлітаємо.\n\nНьют приготувала кілька гірокоптерів на вершині вежі. Зустрінься з нею, щоб швидко повернутися у Варіятівку. А ми тут приберемо.', 'progress': 'Скажи, що тобі це вдалося? Тобі завжди все вдається. Покажи мою красуню!', 'completion': "Ось, що я хотів побачити! Завдяки цій красуні я швидко поверну флот у стрій.\n\nТи знаєш, що мені подобається, {ім'я:к}. А я знаю, що подобається тобі — візьми це."}
# {'title': 'Ласкаво просимо до Високого берега!', 'objective': 'Убийте 10 нападників з Орди у Високому березі.', 'description': "Ласкаво просимо в нагір'я, солдате. Ти {стать:прийшов:прийшла} вчасно.\n\nВійська Орди щойно почали повітряний штурм. Виступай та зроби щось з цим. Знищ їх!", 'progress': 'Доведеться вбити ще кількох, солдате.', 'completion': 'Ось так краще. Звідси ми зможемо знищити їх.'}
# {'title': 'Гра з вогнем', 'objective': 'Зберіть 10 мішків, наповнених порохом.', 'description': "Ха! Пора взятися до справи, {ім'я:к}. Схоже, у Високого берега виникла проблема з дирижаблем, цей корабель просто розносить стіни вщент.\n\nСлухай, у мене є одна ідея, настільки дурна, що аж геніальна. Мені тільки потрібен порох.\n\nЗбери все, що зможеш знайти навколо Високого берега та зустрінься зі мною на торговій площі!", 'progress': 'Мені потрібен порох! Більше пороху! Більше, більше, більше!', 'completion': 'Так, цього вистачить.\n\n<Кремньостріл набиває собі повний рот пороху.>\n\nОх, свіженький. Запаморочливий. Тонкий помол з Багрянокряжжя з домішками сірки із Західного краю та легким післясмаком. У Високому березі є добрі речі.'}
# {'title': 'Висока ціль', 'objective': 'Дочекайтесь, поки Фарґо Кремезний Курок відправить вас на дирижабль, а потім закладіть його вибухівку в нижньому відсіку.', 'description': "Поглянь, {ім'я:к}. Я знайшов найбільшу гармату у Високому березі! Ми спробуємо техніку, яку передав мені мій тато, а йому його тато, а йому його тато, незадовго до того, як підірвався.\n\nВона називається «постріл {клас:о}».\n\nБереш {расу:з} {клас:з}, заряджаєш {стать:його:її} в гігантську гармату, а потім... О, розслабся. Зазвичай це працює.\n\nВізьми цю вибухівку, а потім чекай тут, поруч зі мною. Як тільки той дирижаблик наблизиться, я вистрелю тобою на палубу. Заклади вибухівку в його черево і... ну, не знаю, придумаєш щось по ходу.", 'progress': 'Немає такої проблеми, яку не можна було б вирішити за допомогою бомби.', 'completion': "<Кремезний Курок витирає сльози.>\n\nО, {ім'я:к}. {ім'я:к}!\n\nЦе... було прекрасно."}
# {'title': 'Курдран чекає', 'objective': 'Поговоріть з Курдраном Громовим Молотом у фортеці Високого берега, що в Сутінковій верховині.', 'description': "Схоже, атака припинилася, {ім'я:к}. Шкода, що ми так і не скористалися {клас:о} ракетою.\n\nУ будь-якому разі, Курдран Громовий Молот сидить на верхівці фортеці та, певно, захоче вшанувати тебе, як {стать:героя:героїню}. Ти це {стать:заслужив:заслужила}! Іди поговори з ним!\n\nА я піду вперед і розвідаю пляж.", 'progress': 0, 'completion': 'Сам король відправив тебе? Приємно чути, що у Штормовії все добре.\n\nЯ очікував, що війська будуть більшими, але кажуть, що флот Альянсу потрапив у засідку Орди по дорозі сюди. Вони дали гідну відсіч, але флот розгромлено.\n\nЯкщо ми хочемо просунутися вперед тут, у верховині, нам потрібна допомога таких {стать:героїв:героїнь}, як ти.'}
# {'title': 'Дика, дика, дика весільна церемонія', 'objective': 'Поговоріть з Ґрунді МакҐрафом, щоб розпочати весільну церемонію. Знищте всіх членів Сутінкового Молота, які спробують завадити вам!', 'description': "Ми готові починати, {ім'я:к}!\n\nАле я маю інформацію, що Сутінковий Молот може спробувати зірвати церемонію, щоб деморалізувати та знищити Клан Дикого Молота. Може бути небезпечно!\n\nЗ цієї причини церемонію буду проводити я, щоб наречена та наречений були поруч зі мною. Звучить, як план, правда? Чудово!\n\nОскільки її батько мертвий, а брат — боярин, Фанні попросила, щоб ти {стать:провів:провела} її до вівтаря. Яка честь! Поговори зі мною, коли будеш {стать:готовий:готова} почати.", 'progress': 'Чудовий день для дикого весілля...', 'completion': "Ми це зробили, {ім'я:к}! Б'ючись пліч-о-пліч з цією... істотою, ми дійсно об'єднали весь Клан Дикого Молота. Глави сімейств об'єдналися, я ніколи не бачив їх такими. Пий, {ім'я:к}, і святкуй!\n\nЗвісно, наша робота тільки починається. Я об'єднаю нові сили Клану Дикого Молота з рештою Альянсу та почну підготовку до штурму Сутінкової твердині.\n\nЯ впевнений, що ми скоро знову зустрінемось."}
# {'title': 'Вступ королеви драконів', 'objective': 'Знайдіть Лірастразу в Крузі Життя, що в Сутінковій верховині.', 'description': 'Вітаю, {раса:к}. Шкода, що ми не зустрілися за більш сприятливих обставин. Світ висить на волосині й усе, що створили Титани, може бути знищено.\n\nМені дуже сумно, але моє рішення остаточне. Смертекрил — жахливе створіння, яке колись було Хранителем Землі й моїм другом — має бути знищене.\n\nЯ підготувала місце на вершині верховини, на захід від Цинобрового бастіону, де я зможу покласти йому край. Знайди Круг Життя та поговори з Лірастразою. Я приєднаюся до вас там.', 'progress': None, 'completion': 'Знову вітаю, {раса:к}. Я чула, що ти {стать:допоміг:допомогла} нам просунутися до Ґрім-Батолу. Дякую!\n\nАлекстраза освятила цю землю в надії заманити сюди Смертекрила. Вона проведе церемонію, щоб виманити його, а потім знищить у цьому священному колі.\n\nСподіваємось, її план спрацює.'}
# {'title': 'Битва на життя і смерть', 'objective': 'Осідлайте багряного вартового та вбийте 8 присмеркових тінедраконів.', 'description': 'Алекстраза та Смертекрил злетіли в небо над Ґрім-Батолом! Її план провалився — Драконяча королева опинилася за межами Круга Життя, який вона підготувала раніше. Нам потрібно підтримати її всім, що у нас є.\n\nПоспішай! Сідай на одного з багряних вартових позаду мене.\n\nЯкщо ми знайдемо присмеркових драконів, які допомагають Смертекрилу, нам доведеться вбити їх. Сідай, швидко!', 'progress': "Битва триває, {ім'я:к}.", 'completion': 'Завдяки твоїм швидким діям Драконяча королева все ще жива. Її повертають у Храм Драконозародження, щоб вона одужала.\n\nАле битва не пройшла безслідно. Смертекрил важко поранений. Підозрюю, що він сховається, щоб відновитися. Алекстраза дала нам час, щоб завдати удару!'}
# {'title': 'Сутінкове узбережжя', 'objective': 'Поговоріть з лейтенантом Фоксом у Високому березі, що в Сутінковій верховині.', 'description': "Гаразд, просто сядь на гідролітак позаду мене, і я відвезу тебе у верховину.\n\nТреба доповісти хлопчині на ім'я лейтенант Фокс. Я пообіцяв королю, що ми доберемося туди дуже швидко, тому взяв на себе сміливість позбутися зайвої ваги. Наприклад, ременів безпеки. Парашутів. Карт. Стабілізаторів. Шасі.\n\nЯ все одно ніколи не ", 'progress': '', 'completion': 'Останнє, що я очікував побачити, це те, як ви падаєте з неба. На Високий берег напали!'}
# {'title': 'Стримування Драконової Пащі', 'objective': 'Убийте мародерів Драконової Пащі та зберіть 8 знаків Драконової Пащі. У відомих персонажів з руїн Гріммара також будуть знаки.', 'description': 'З твоєю допомогою ми добряче відлупцювали Драконову Пащу, але вони продовжують щодня атакувати околиці Гріммара. Ми повинні продовжувати тиснути на них!\n\nПовертайся в бій, що вирує в руїнах Гріммара на півдні та південному заході. Вбий мародерів Драконової Пащі та збери знаки, які носять їхні найвеличніші воїни.', 'progress': 'Як там з боєм, {клас:к}?', 'completion': 'Так, саме так це і робиться! З такими {стать:героями:героїнями}, як ти, я пишаюся тим, що є частиною Альянсу.'}
# {'title': 'Бийся, як дикий молот', 'objective': "Зберіть 10 бочок гріммарського елю в руїнах Гріммара. Обережно, він добряче б'є в голову!", 'description': "<Бланді перевертає свою чашку.>\n\nУ мене скінчився ель, {ім'я:к}!\n\nВирушай в руїни Гріммара та пошукай, чи не залишилося там чогось, поки ці смердючі орки з клану Драконової Пащі не добралися до нього.\n\nМожеш трохи випити і сам{стать:ий:а}. Кухоль найкращого старого гріммарського елю зміцнить твої бойові навички.", 'progress': 'Є щось?', 'completion': 'О, так, непоганий улов!\n\nЦього мені вистачить до... ну, скажімо, до завтра.'}
# {'title': 'Їжу з собою не брати', 'objective': 'Зберіть 10 запасів їжі Громомолота в руїнах Гріммара.', 'description': 'Біженці з поля бою продовжують прибувати в Гріммар, а я голодний! Тобто вони. Біженці, вони голодні.\n\nПринеси мені їжу з руїн Гріммара! Прочеши руїни на півдні, сході та південному заході в пошуках їжі, що залишилася. Особливо тих великих шматків шинки. Я їх просто обожнюю! Тобто, біженці обожнюють.\n\nІ якщо зможеш, знайди ще ті маленькі коктейльні сосиски.', 'progress': 'Їжу {стать:приніс:принесла}?', 'completion': 'О, ти якраз вчасно! Я так важко працював, щоб нагодувати цих голодних біженців, що сам зголоднів. Так, сер.'}
# {'title': 'Повернення воєводи Халтара', 'objective': 'Убийте воєводу Халтара.', 'description': "Він знову взявся за своє, {ім'я:к}. Воєвода Халтар... жах нашого краю. Його та його дракончика бачили на півдні, вони наводили безлад в руїнах Гріммара.\n\n{ім'я:к}, убий Халтара! Як тільки ти почнеш, ми пришлемо підкріплення.", 'progress': None, 'completion': "Неприємна справа, але ти все одно {стать:молодець:молодчинка}. Дякую, {ім'я:к}."}
# {'title': 'Поставка пива', 'objective': 'Поговоріть з Гаммельгандом на дорозі, що веде на південний схід від гори Громового Удару, та проведіть караван до Кіртодолу.', 'description': "Після весілля моєї сестри я розсмакував той грімоварівський лагер, який Курдран привіз з Дун-Морогу. Ми замовили ще, але на наш караван постійно нападає Драконова Паща!\n\nВирушай на південний схід від гори Громового Удару та наздожени караван. Знайди там хлопця на ім'я Гаммельганд і допоможи йому провезти пиво через перевал.\n\nДоведи його до Кіртодолу, а там ми вже розберемось.", 'progress': None, 'completion': "І не кажи. Ніколи б не подумав, що мені сподобається імпортне пиво. Дякую, {ім'я:к}!"}
# {'title': 'Розгромити Дикогром', 'objective': 'Вбийте воїнів Дикогрому та зберіть 8 знаків відмінності Дикогрому. У мешканців руїн Гріммара також будуть знаки відмінності.', 'description': 'Дикогром посмілішав з новими союзниками з Альянсу. Вони наважуються переправлятися через річку. Віджени їх!\n\nЗнайди та розгроми воїнів Дикогрому, які воюють у річищі та руїнах Гріммара на північному березі. Кращі з них носять знаки відмінності. Збери їх для мене, щоб довести свою відданість справі Драконової Пащі.', 'progress': 'Покажи мені зібрані знаки відмінності, {клас:к}.', 'completion': 'Що ми маємо? {стать:Один:Одна} {клас:н} Орди може знищити десятки Дикогрому. На що вони тепер можуть сподіватися?'}
# {'title': 'Тотальна війна', 'objective': 'Розбийте 10 бочок з елем Гріммара в руїнах Гріммара.', 'description': "Деякі з дикогривих все ще сподіваються повернути руїни Гріммара, що на північ, за рікою. Спали їх! Розбий бочки з елем Гріммара. Цього зілля досить, щоб вибухнути, якщо його підпалити.\n\nНе питай, чому.\n\nІ не питай, як вони п'ють цю гидоту.", 'progress': None, 'completion': "Так, так. Спали їх, як би ти палив бабаків в їхніх норах...\n\nМолодець, {ім'я:к}."}
# {'title': 'Ще одна паща, яку потрібно годувати', 'objective': 'Зберіть 10 запасів їжі Громового Молота в руїнах Гріммара.', 'description': '<У Гріффа бурчить у животі.>\n\nЯ все ще голодний. Це як... кожного дня я голодний.\n\nЧув, що в руїнах Гріммара, що за річкою, на північ, там, де йдуть бої, заховано ще більше їжі. Принеси мені щось.', 'progress': '<Гріфф облизує губи.>', 'completion': '<Гріфф жадібно хапає купу їжі, якої вистачило б, щоб нагодувати десятки людей.>\n\nЧудово! Цього вистачить на... кілька годин!'}
# {'title': 'Збивай їх з ніг!', 'objective': 'Використайте гачок з шипами, щоб скинути та вбити 4 вершників Гріммарських грифонів.', 'description': 'Клан Громового Молота тренує бойових грифонів швидше, ніж ми підкорюємо драконів. Ми не можемо дозволити їм перевершити нас!\n\nПолюй на вершників грифонів, що літають над річкою на північ від Кривавої ущелини. Візьми цей гачок і кидай його в них, коли вони пролітатимуть повз. Це скине їх з грифонів просто до твоїх ніг. Вбий їх!', 'progress': None, 'completion': "В тебе це добре виходить, {ім'я:к}.\n\nЗбивай клан Громового Молота з їхніх грифонів, і вони нічого не варті!"}
# {'title': 'Вбити верховного шамана', 'objective': 'Убийте верховного шамана МакКілліґана.', 'description': "Наші розвідники повідомляють, що верховний шаман МакКілліґан покинув Гріммар і воює в руїнах Гріммара, що на північний захід звідси, за річкою.\n\nВін небезпечний, {ім'я:к}, на його руках кров багатьох з клану Драконової Пащі. Ми знищимо його, це не обговорюється.\n\nПитання в іншому: чи зможеш ти здобути славу за його вбивство?", 'progress': None, 'completion': 'Верховного шамана повалено! Гріммар, безсумнівно, спробує відправити когось іншого, але сьогодні клан Драконової Пащі тріумфує.'}
# {'title': 'Шалена поїздка містера Золотокопа', 'objective': 'Прокатайтеся в шахтному вагонетці з новачком Золотокопом до кінця маршруту.', 'description': 'Гаразд, {ім\'я:к}, нам потрібно дістатися до порталу землі в кінці печери.\n\nЯ вже "підготував" нам транспорт. Навіщо йти пішки, якщо можна поїхати зі стилем? Сподіваюсь, ти не проти шахтних вагонеток.\n\nСкажеш, коли будеш {стать:готовий:готова}.', 'progress': None, 'completion': 'О, ні! Моя зброя та тотеми!\n\nВони знищені!!!'}

# %%
## Fetching all files from Crowdin for further usage. Takes about 1 minute. 

crowdin_files = dict()
offset = 0
page_size = 500
while (True):
    files = crowdin_client.source_files.list_files(CROWDIN_PROJECT_ID, offset=offset, limit=page_size)
    if not files['data']:
        break
    for file in files['data']:
        file_id = file['data']['id']
        file_path = file['data']['path']
        crowdin_files[file_path] = file_id
    offset += page_size

# %%
def get_quest_filename(row):
    quest_id = row['id']
    quest_title = row['title_en']
    valid_chars = frozenset('-.() abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')
    return ''.join(c for c in quest_title if c in valid_chars) + '_' + str(quest_id)

def get_path_for_quest(row):
    path = '/quests' + (f"_{row['expansion']}" if row['expansion'] != 'classic' else '')
    filename = get_quest_filename(row)
    path = path + f"/{row['cat']}/{filename}.xml"
    return path


def upload_translation(string_data, translation_text):
    crowdin_client.source_strings.get_string(string_data['id'])
    try:
        crowdin_client.string_translations.add_translation(stringId=string_data['id'], languageId='uk', text=translation_text)
        print(f"Uploaded translation for string#{string_data['id']}")
    except:
        print(f"Error uploading translation for string#{string_data['id']}")

def upload_translations(row):
    path = get_path_for_quest(row)
    file_id = crowdin_files.get(path)
    if not file_id:
        print(f"File #{file_id} not found for {path}.")
        return
    strings = crowdin_client.source_strings.list_strings(fileId=file_id)['data']
    strings_by_key = {string_data['data']['identifier']: string_data['data'] for string_data in strings}
    upload_translation(strings_by_key['TITLE'], row['title_uk'])
    if strings_by_key.get('OBJECTIVE') and row['objective_uk']:
        upload_translation(strings_by_key['OBJECTIVE'], row['objective_uk'])
    if strings_by_key.get('DESCRIPTION') and row['description_uk']:
        upload_translation(strings_by_key['DESCRIPTION'], row['description_uk'])
    if strings_by_key.get('PROGRESS') and row['progress_uk']:
        upload_translation(strings_by_key['PROGRESS'], row['progress_uk'])
    if strings_by_key.get('COMPLETION') and row['completion_uk']:
        upload_translation(strings_by_key['COMPLETION'], row['completion_uk'])


def add_comment(string_data, translation_text):
    crowdin_client.source_strings.get_string(string_data['id'])
    try:
        crowdin_client.string_comments.add_string_comment(stringId=string_data['id'], text=translation_text, targetLanguageId='uk', type='comment')
        print(f"Added comment for string#{string_data['id']}")
    except:
        print(f"Error adding comment for string#{string_data['id']}")

def add_comments(row):
    path = get_path_for_quest(row)
    file_id = crowdin_files.get(path)
    if not file_id:
        print(f"File #{file_id} not found for {path}.")
        return
    strings = crowdin_client.source_strings.list_strings(fileId=file_id)['data']
    strings_by_key = {string_data['data']['identifier']: string_data['data'] for string_data in strings}
    add_comment(strings_by_key['TITLE'], row['title_uk'])
    if strings_by_key.get('OBJECTIVE') and row['objective_uk']:
        add_comment(strings_by_key['OBJECTIVE'], row['objective_uk'])
    if strings_by_key.get('DESCRIPTION') and row['description_uk']:
        add_comment(strings_by_key['DESCRIPTION'], row['description_uk'])
    if strings_by_key.get('PROGRESS') and row['progress_uk']:
        add_comment(strings_by_key['PROGRESS'], row['progress_uk'])
    if strings_by_key.get('COMPLETION') and row['completion_uk']:
        add_comment(strings_by_key['COMPLETION'], row['completion_uk'])

# %%
## Uploading translations to Crowdin. Takes about 2.5 sec per quest
for _, row in filtered_df.iterrows():
    filename = get_quest_filename(row)
    try:
        # upload_translations(row)
        add_comments(row)
        print(f"Uploaded translations for {filename}")
    except Exception as e:
        print(f"Error uploading translations for {filename}: {e}")
# Out:
# Added comment for string#115534
# Added comment for string#115536
# Added comment for string#115538
# Added comment for string#150402
# Added comment for string#150404
# Uploaded translations for Emergency Aid_26538
# Added comment for string#116254
# Added comment for string#116256
# Added comment for string#116258
# Added comment for string#150744
# Uploaded translations for Stalled Negotiations_26539
# Added comment for string#115414
# Added comment for string#115416
# Added comment for string#115418
# Added comment for string#150348
# Added comment for string#150350
# Uploaded translations for Dangerous Compassion_26540
# Added comment for string#115816
# Added comment for string#115818
# Added comment for string#115820
# Added comment for string#150536
# Added comment for string#150538
# Uploaded translations for Madness_26549
# Added comment for string#115906
# Added comment for string#115908
# Added comment for string#115910
# Added comment for string#150572
# Uploaded translations for Negotiations Terminated_26608
# Added comment for string#116656
# Added comment for string#116658
# Added comment for string#116660
# Added comment for string#150932
# Uploaded translations for You Say You Want a Revolution_26619
# Added comment for string#115738
# Added comment for string#115740
# Added comment for string#115742
# Added comment for string#150498
# Added comment for string#150500
# Uploaded translations for Insurrection_26621
# Added comment for string#115432
# Added comment for string#115434
# Added comment for string#115436
# Added comment for string#150364
# Uploaded translations for Death to Morghor_26622
# Added comment for string#115876
# Added comment for string#115878
# Added comment for string#115880
# Added comment for string#150558
# Added comment for string#150560
# Uploaded translations for Muddied Waters_26784
# Added comment for string#116122
# Added comment for string#116124
# Added comment for string#116126
# Added comment for string#150690
# Uploaded translations for Securing the Beach Head_26786
# Added comment for string#115372
# Added comment for string#115374
# Error adding comment for string#115376
# Added comment for string#150324
# Added comment for string#150326
# Uploaded translations for Cementing Our Victory_26788
# Added comment for string#116464
# Added comment for string#116466
# Added comment for string#116468
# Added comment for string#150844
# Uploaded translations for The Warchief Will be Pleased_26798
# Added comment for string#116086
# Added comment for string#116088
# Added comment for string#116090
# Added comment for string#150664
# Uploaded translations for Return to the Highlands_26840
# Added comment for string#116104
# Added comment for string#116106
# Added comment for string#116108
# Added comment for string#150678
# Added comment for string#150680
# Uploaded translations for Salvage Operation_27177
# Added comment for string#115888
# Added comment for string#115890
# Added comment for string#115892
# Added comment for string#150564
# Uploaded translations for Naga Reinforcements_27178
# Added comment for string#116194
# Added comment for string#116196
# Added comment for string#116198
# Added comment for string#150714
# Uploaded translations for Sirens Song_27200
# Added comment for string#116500
# Added comment for string#116502
# Added comment for string#116504
# Added comment for string#150860
# Added comment for string#150862
# Uploaded translations for Torn Ground_27299
# Added comment for string#116062
# Added comment for string#116064
# Added comment for string#116066
# Added comment for string#150654
# Uploaded translations for Pushing Back_27300
# Added comment for string#116530
# Added comment for string#116532
# Added comment for string#116534
# Added comment for string#150872
# Uploaded translations for Unbroken_27301
# Added comment for string#116188
# Added comment for string#116190
# Added comment for string#116192
# Added comment for string#150710
# Added comment for string#150712
# Uploaded translations for Simple Solutions_27302
# Added comment for string#115840
# Added comment for string#115842
# Added comment for string#115844
# Added comment for string#150548
# Added comment for string#150550
# Uploaded translations for Mercy for the Bound_27303
# Added comment for string#115972
# Added comment for string#115974
# Added comment for string#115976
# Added comment for string#150608
# Uploaded translations for Our Boys on the Shore_27338
# Added comment for string#116110
# Added comment for string#116112
# Added comment for string#116114
# Added comment for string#150682
# Added comment for string#150684
# Uploaded translations for Scouting the Shore_27341
# Added comment for string#115792
# Added comment for string#115794
# Added comment for string#115796
# Added comment for string#153940
# Added comment for string#150524
# Uploaded translations for Landgrab_27366
# Added comment for string#116422
# Added comment for string#116424
# Added comment for string#116426
# Added comment for string#150822
# Uploaded translations for The Maw of Madness_27374
# Added comment for string#116476
# Added comment for string#116478
# Added comment for string#116480
# Added comment for string#150848
# Uploaded translations for The Weeping Wound_27375
# Added comment for string#116416
# Added comment for string#116418
# Added comment for string#116420
# Added comment for string#150818
# Added comment for string#150820
# Uploaded translations for The Maw of Isorath_27376
# Added comment for string#115444
# Added comment for string#115446
# Added comment for string#115448
# Added comment for string#150366
# Uploaded translations for Devoured_27377
# Added comment for string#116482
# Added comment for string#116484
# Added comment for string#116486
# Added comment for string#150850
# Uploaded translations for The Worldbreaker_27378
# Added comment for string#116458
# Added comment for string#116460
# Added comment for string#116462
# Added comment for string#150840
# Added comment for string#150842
# Uploaded translations for The Terrors of Isorath_27379
# Added comment for string#115930
# Added comment for string#115932
# Added comment for string#115934
# Added comment for string#150586
# Uploaded translations for Nightmare_27380
# Added comment for string#116140
# Added comment for string#116142
# Added comment for string#116144
# Added comment for string#150700
# Added comment for string#150702
# Uploaded translations for Shredderectomy_27433
# Added comment for string#116152
# Added comment for string#116154
# Added comment for string#116156
# Added comment for string#150704
# Added comment for string#150706
# Uploaded translations for Siege Tank Rescue_27468
# Added comment for string#116566
# Added comment for string#116568
# Added comment for string#116570
# Added comment for string#150882
# Added comment for string#150884
# Uploaded translations for Warm Welcome_27485
# Added comment for string#116572
# Added comment for string#116574
# Added comment for string#116576
# Added comment for string#150886
# Added comment for string#150888
# Uploaded translations for Warm Welcome_27486
# Added comment for string#116146
# Added comment for string#116148
# Added comment for string#116150
# Added comment for string#150674
# Added comment for string#150676
# Uploaded translations for SI7 Drop_27490
# Added comment for string#115768
# Added comment for string#115770
# Added comment for string#115772
# Added comment for string#150510
# Added comment for string#150512
# Uploaded translations for Korkron Drop_27491
# Added comment for string#115954
# Added comment for string#115956
# Added comment for string#115958
# Added comment for string#150596
# Added comment for string#150598
# Uploaded translations for Ogres  Ettins_27492
# Added comment for string#115960
# Added comment for string#115962
# Added comment for string#115964
# Added comment for string#150600
# Added comment for string#150602
# Uploaded translations for Ogres  Ettins_27493
# Added comment for string#115852
# Added comment for string#115854
# Added comment for string#115856
# Uploaded translations for Move the Mountain_27494
# Added comment for string#115858
# Added comment for string#115860
# Added comment for string#115862
# Uploaded translations for Move the Mountain_27495
# Added comment for string#115354
# Added comment for string#115356
# Added comment for string#115358
# Uploaded translations for Call in the Artillery_27496
# Added comment for string#115360
# Added comment for string#115362
# Added comment for string#115364
# Added comment for string#150320
# Uploaded translations for Call in the Artillery_27497
# Added comment for string#116164
# Added comment for string#116166
# Added comment for string#116168
# Uploaded translations for Signal the Attack_27498
# Added comment for string#116170
# Added comment for string#116172
# Added comment for string#116174
# Uploaded translations for Signal the Attack_27499
# Added comment for string#115636
# Added comment for string#115638
# Added comment for string#115640
# Added comment for string#150454
# Added comment for string#150456
# Uploaded translations for Four Heads are Better than None_27500
# Added comment for string#115642
# Added comment for string#115644
# Added comment for string#115646
# Added comment for string#150458
# Added comment for string#150460
# Uploaded translations for Four Heads are Better than None_27501
# Added comment for string#116536
# Added comment for string#116538
# Added comment for string#116540
# Uploaded translations for Up to the Citadel_27502
# Added comment for string#116542
# Added comment for string#116544
# Added comment for string#116546
# Uploaded translations for Up to the Citadel_27503
# Added comment for string#115558
# Added comment for string#115560
# Added comment for string#115562
# Added comment for string#150412
# Uploaded translations for Even Dragons Bleed_27504
# Added comment for string#115474
# Added comment for string#115476
# Added comment for string#115478
# Added comment for string#150376
# Added comment for string#150378
# Uploaded translations for Draconic Mending_27505
# Added comment for string#115810
# Added comment for string#115812
# Added comment for string#115814
# Added comment for string#150532
# Added comment for string#150534
# Uploaded translations for Life from Death_27506
# Added comment for string#115540
# Added comment for string#115542
# Added comment for string#115544
# Added comment for string#150406
# Uploaded translations for Encroaching Twilight_27507
# Added comment for string#115582
# Added comment for string#115584
# Added comment for string#115586
# Added comment for string#150424
# Added comment for string#150426
# Uploaded translations for Far from the Nest_27508
# Added comment for string#115324
# Added comment for string#115326
# Added comment for string#115328
# Added comment for string#150304
# Uploaded translations for Breach in the Defenses_27509
# Added comment for string#115288
# Added comment for string#115290
# Added comment for string#115292
# Added comment for string#150292
# Uploaded translations for Bird Down Bird Down_27514
# Added comment for string#116092
# Added comment for string#116094
# Added comment for string#116096
# Added comment for string#150666
# Added comment for string#150668
# Uploaded translations for Rootsll Do Er_27515
# Added comment for string#116644
# Added comment for string#116646
# Added comment for string#116648
# Added comment for string#150926
# Added comment for string#150928
# Uploaded translations for Wings Over Highbank_27516
# Added comment for string#115240
# Added comment for string#115242
# Added comment for string#115244
# Added comment for string#150266
# Added comment for string#150268
# Uploaded translations for Any Portal in a Storm_27537
# Added comment for string#116440
# Added comment for string#116442
# Added comment for string#116444
# Added comment for string#150830
# Added comment for string#150832
# Uploaded translations for The Perfect Poultice_27538
# Added comment for string#116470
# Added comment for string#116472
# Added comment for string#116474
# Added comment for string#150846
# Uploaded translations for The Way is Open_27545
# Added comment for string#115732
# Added comment for string#115734
# Added comment for string#115736
# Added comment for string#150496
# Uploaded translations for In Defense of the Redoubt_27564
# Added comment for string#115990
# Added comment for string#115992
# Added comment for string#115994
# Added comment for string#150616
# Uploaded translations for Patchwork Command_27576
# Added comment for string#116428
# Added comment for string#116430
# Added comment for string#116432
# Added comment for string#150824
# Uploaded translations for The Northern Flank_27583
# Added comment for string#115312
# Added comment for string#115314
# Added comment for string#115316
# Added comment for string#150300
# Uploaded translations for Blood in the Surf_27584
# Added comment for string#116128
# Added comment for string#116130
# Added comment for string#116132
# Added comment for string#150692
# Added comment for string#150694
# Uploaded translations for Shells on the Sea Shore_27586
# Added comment for string#116176
# Added comment for string#116178
# Added comment for string#116180
# Uploaded translations for Signal the Attack_27588
# Added comment for string#116182
# Added comment for string#116184
# Added comment for string#116186
# Uploaded translations for Signal the Attack_27590
# Added comment for string#115300
# Added comment for string#115302
# Added comment for string#115304
# Added comment for string#150296
# Uploaded translations for Blast Him_27606
# Added comment for string#116452
# Added comment for string#116454
# Added comment for string#116456
# Added comment for string#150838
# Uploaded translations for The Southern Flank_27607
# Added comment for string#115648
# Added comment for string#115650
# Added comment for string#115652
# Uploaded translations for Four Heads are Better than None_27608
# Added comment for string#115654
# Added comment for string#115656
# Added comment for string#115658
# Uploaded translations for Four Heads are Better than None_27609
# Added comment for string#116116
# Added comment for string#116118
# Added comment for string#116120
# Added comment for string#150686
# Added comment for string#150688
# Uploaded translations for Scouting the Shore_27610
# Added comment for string#115318
# Added comment for string#115320
# Added comment for string#115322
# Added comment for string#150302
# Uploaded translations for Blood on the Sand_27611
# Added comment for string#115624
# Added comment for string#115626
# Added comment for string#115628
# Added comment for string#150448
# Uploaded translations for Firebeards Patrol_27621
# Added comment for string#115846
# Added comment for string#115848
# Added comment for string#115850
# Added comment for string#150552
# Uploaded translations for Mo Better Shredder_27622
# Added comment for string#115750
# Added comment for string#115752
# Added comment for string#115754
# Added comment for string#150504
# Uploaded translations for Just You and Mathias_27636
# Added comment for string#115756
# Added comment for string#115758
# Added comment for string#115760
# Uploaded translations for Just You and Mathias_27637
# Added comment for string#115744
# Added comment for string#115746
# Added comment for string#115748
# Added comment for string#150502
# Uploaded translations for Just You and Garona_27638
# Added comment for string#140046
# Added comment for string#140048
# Added comment for string#140050
# Uploaded translations for Just You and Garona_27639
# Added comment for string#115516
# Added comment for string#115518
# Added comment for string#115520
# Added comment for string#150396
# Uploaded translations for Dunwalds Dont Die_27640
# Added comment for string#116614
# Added comment for string#116616
# Added comment for string#116618
# Added comment for string#150910
# Uploaded translations for While Meeting The Family_27641
# Added comment for string#116158
# Added comment for string#116160
# Added comment for string#116162
# Added comment for string#150708
# Uploaded translations for Sifting Through The Wreckage_27642
# Added comment for string#115468
# Added comment for string#115470
# Added comment for string#115472
# Added comment for string#150374
# Uploaded translations for Donnelly Dunwald_27643
# Added comment for string#115552
# Added comment for string#115554
# Added comment for string#115556
# Added comment for string#150410
# Uploaded translations for Eoin Dunwald_27644
# Added comment for string#115366
# Added comment for string#115368
# Added comment for string#115370
# Added comment for string#150322
# Uploaded translations for Cayden Dunwald_27645
# Added comment for string#115606
# Added comment for string#115608
# Added comment for string#115610
# Added comment for string#150440
# Added comment for string#150442
# Uploaded translations for Finding Beak_27646
# Added comment for string#115246
# Added comment for string#115248
# Added comment for string#115250
# Added comment for string#150270
# Added comment for string#150272
# Uploaded translations for Anything But Water_27647
# Added comment for string#115966
# Added comment for string#115968
# Added comment for string#115970
# Added comment for string#150604
# Added comment for string#150606
# Uploaded translations for Once More Into The Fire_27648
# Added comment for string#115204
# Added comment for string#115206
# Added comment for string#115208
# Added comment for string#150248
# Added comment for string#150250
# Uploaded translations for A Steady Supply_27649
# Added comment for string#115690
# Added comment for string#115692
# Added comment for string#115694
# Added comment for string#150476
# Uploaded translations for Home Again_27650
# Added comment for string#115462
# Added comment for string#115464
# Added comment for string#115466
# Added comment for string#150372
# Uploaded translations for Doing It Like a Dunwald_27651
# Added comment for string#115420
# Added comment for string#115422
# Added comment for string#115424
# Added comment for string#150352
# Added comment for string#150354
# Uploaded translations for Dark Assassins_27652
# Added comment for string#115426
# Added comment for string#115428
# Added comment for string#115430
# Added comment for string#150356
# Added comment for string#150358
# Uploaded translations for Dark Assassins_27653
# Added comment for string#115336
# Added comment for string#115338
# Added comment for string#115340
# Added comment for string#150308
# Added comment for string#150310
# Uploaded translations for Bring the Hammer Down_27654
# Added comment for string#115342
# Added comment for string#115344
# Added comment for string#115346
# Added comment for string#150312
# Uploaded translations for Bring the Hammer Down_27655
# Added comment for string#115672
# Added comment for string#115674
# Added comment for string#115676
# Added comment for string#150468
# Uploaded translations for Help from the Earthcaller_27657
# Added comment for string#115678
# Added comment for string#115680
# Added comment for string#115682
# Added comment for string#150470
# Uploaded translations for Help from the Earthcaller_27658
# Added comment for string#116020
# Added comment for string#116022
# Added comment for string#116024
# Added comment for string#150628
# Uploaded translations for Portal Overload_27659
# Added comment for string#116248
# Added comment for string#116250
# Added comment for string#116252
# Added comment for string#150742
# Uploaded translations for Spirit of the Loch_27660
# Added comment for string#115612
# Added comment for string#115614
# Added comment for string#115616
# Added comment for string#150444
# Uploaded translations for Fire the Cannon_27661
# Added comment for string#116524
# Added comment for string#116526
# Added comment for string#116528
# Added comment for string#150870
# Uploaded translations for Unbinding_27662
# Added comment for string#115450
# Added comment for string#115452
# Added comment for string#115454
# Added comment for string#150368
# Uploaded translations for Distract Them for Me_27688
# Added comment for string#115456
# Added comment for string#115458
# Added comment for string#115460
# Added comment for string#150370
# Uploaded translations for Distract Them for Me_27689
# Added comment for string#115894
# Added comment for string#115896
# Added comment for string#115898
# Added comment for string#150570
# Uploaded translations for Narkrall the Drake-Tamer_27690
# Added comment for string#116344
# Added comment for string#116346
# Added comment for string#116348
# Added comment for string#150784
# Added comment for string#150786
# Uploaded translations for The Elementium Axe_27695
# Added comment for string#116350
# Added comment for string#116352
# Added comment for string#116354
# Added comment for string#150788
# Added comment for string#150790
# Uploaded translations for The Elementium Axe_27696
# Added comment for string#115486
# Added comment for string#115488
# Added comment for string#115490
# Added comment for string#150382
# Uploaded translations for Dragon Unchained_27700
# Added comment for string#115492
# Added comment for string#115494
# Added comment for string#115496
# Added comment for string#153938
# Added comment for string#150384
# Uploaded translations for Dragon Unchained_27701
# Added comment for string#115384
# Added comment for string#115386
# Added comment for string#115388
# Added comment for string#150330
# Added comment for string#150332
# Uploaded translations for Coup de Grace_27702
# Added comment for string#115390
# Added comment for string#115392
# Added comment for string#115394
# Added comment for string#150334
# Added comment for string#150336
# Uploaded translations for Coup de Grace_27703
# Added comment for string#115258
# Added comment for string#115260
# Added comment for string#115262
# Uploaded translations for Back to the Elementium Depths_27711
# Added comment for string#115264
# Added comment for string#115266
# Added comment for string#115268
# Added comment for string#150280
# Uploaded translations for Back to the Elementium Depths_27712
# Added comment for string#116578
# Added comment for string#116580
# Added comment for string#116582
# Added comment for string#150890
# Uploaded translations for Water of Life_27719
# Added comment for string#115864
# Added comment for string#115866
# Added comment for string#115868
# Added comment for string#150554
# Uploaded translations for Mr. Goldmines Wild Ride_27720
# Added comment for string#115198
# Added comment for string#115200
# Added comment for string#115202
# Added comment for string#150244
# Added comment for string#150246
# Uploaded translations for A Little on the Side_27742
# Added comment for string#116620
# Added comment for string#116622
# Added comment for string#116624
# Added comment for string#153946
# Added comment for string#150912
# Uploaded translations for While Were Here_27743
# Added comment for string#116098
# Added comment for string#116100
# Added comment for string#116102
# Added comment for string#150670
# Added comment for string#150672
# Uploaded translations for Rune Ruination_27744
# Added comment for string#115186
# Added comment for string#115188
# Added comment for string#115190
# Added comment for string#150238
# Added comment for string#150240
# Uploaded translations for A Fiery Reunion_27745
# Added comment for string#116506
# Added comment for string#116508
# Added comment for string#116510
# Added comment for string#150864
# Uploaded translations for Total War_27747
# Added comment for string#116554
# Added comment for string#116556
# Added comment for string#116558
# Added comment for string#150876
# Added comment for string#150878
# Uploaded translations for War Forage_27750
# Added comment for string#115402
# Added comment for string#115404
# Added comment for string#115406
# Added comment for string#150340
# Added comment for string#150342
# Uploaded translations for Crushing the Wildhammer_27751
# Added comment for string#115588
# Added comment for string#115590
# Added comment for string#115592
# Added comment for string#150428
# Added comment for string#150430
# Uploaded translations for Fight Like a Wildhammer_27752
# Added comment for string#115912
# Added comment for string#115914
# Added comment for string#115916
# Added comment for string#150574
# Added comment for string#150576
# Uploaded translations for Never Leave a Dinner Behind_27753
# Added comment for string#115498
# Added comment for string#115500
# Added comment for string#115502
# Added comment for string#150386
# Added comment for string#150388
# Uploaded translations for Dragonmaw Takedown_27754
# Added comment for string#115834
# Added comment for string#115836
# Added comment for string#115838
# Added comment for string#150546
# Uploaded translations for Mathias Needs You_27782
# Added comment for string#115666
# Added comment for string#115668
# Added comment for string#115670
# Added comment for string#150466
# Uploaded translations for Garona Needs You_27783
# Added comment for string#116386
# Added comment for string#116388
# Added comment for string#116390
# Added comment for string#150808
# Uploaded translations for The Hammer of Twilight_27784
# Added comment for string#116392
# Added comment for string#116394
# Added comment for string#116396
# Added comment for string#150810
# Uploaded translations for The Hammer of Twilight_27786
# Added comment for string#116200
# Added comment for string#116202
# Added comment for string#116204
# Added comment for string#150716
# Uploaded translations for Skullcrusher the Mountain_27787
# Added comment for string#116206
# Added comment for string#116208
# Added comment for string#116210
# Added comment for string#150718
# Uploaded translations for Skullcrusher the Mountain_27788
# Added comment for string#116584
# Added comment for string#116586
# Added comment for string#116588
# Added comment for string#150892
# Uploaded translations for Water of Life_27798
# Added comment for string#116602
# Added comment for string#116604
# Added comment for string#116606
# Added comment for string#150902
# Added comment for string#150904
# Uploaded translations for Welcome Relief_27803
# Added comment for string#116434
# Added comment for string#116436
# Added comment for string#116438
# Added comment for string#150826
# Added comment for string#150828
# Uploaded translations for The Only Homes We Have_27804
# Added comment for string#116212
# Added comment for string#116214
# Added comment for string#116216
# Added comment for string#150720
# Added comment for string#150722
# Uploaded translations for Small Comforts_27805
# Added comment for string#115696
# Added comment for string#115698
# Added comment for string#115700
# Added comment for string#150478
# Uploaded translations for Honorable Bearing_27806
# Added comment for string#115378
# Added comment for string#115380
# Added comment for string#115382
# Added comment for string#150328
# Uploaded translations for Clan Mullan_27807
# Added comment for string#116260
# Added comment for string#116262
# Added comment for string#116264
# Added comment for string#150746
# Uploaded translations for Stubborn as a Doyle_27808
# Added comment for string#115618
# Added comment for string#115620
# Added comment for string#115622
# Added comment for string#150446
# Uploaded translations for Firebeard Bellows_27809
# Added comment for string#116374
# Added comment for string#116376
# Added comment for string#116378
# Added comment for string#150802
# Added comment for string#150804
# Uploaded translations for The Fighting Spirit_27810
# Added comment for string#116446
# Added comment for string#116448
# Added comment for string#116450
# Added comment for string#150834
# Added comment for string#150836
# Uploaded translations for The Scent of Battle_27811
# Added comment for string#116410
# Added comment for string#116412
# Added comment for string#116414
# Added comment for string#150816
# Uploaded translations for The Loyalty of Clan Mullan_27812
# Added comment for string#115438
# Added comment for string#115440
# Added comment for string#115442
# Added comment for string#150360
# Added comment for string#150362
# Uploaded translations for Death Worthy of a Dragonmaw_27813
# Added comment for string#115252
# Added comment for string#115254
# Added comment for string#115256
# Added comment for string#150274
# Added comment for string#150276
# Uploaded translations for Anything We Can Get_27814
# Added comment for string#116218
# Added comment for string#116220
# Added comment for string#116222
# Added comment for string#150724
# Added comment for string#150726
# Uploaded translations for Somethin for the Boys_27815
# Added comment for string#116008
# Added comment for string#116010
# Added comment for string#116012
# Added comment for string#150622
# Uploaded translations for Personal Request_27816
# Added comment for string#115510
# Added comment for string#115512
# Added comment for string#115514
# Added comment for string#150392
# Added comment for string#150394
# Uploaded translations for Dropping the Hammer_27817
# Added comment for string#116296
# Added comment for string#116298
# Added comment for string#116300
# Uploaded translations for The Crucible of Carnage The Bloodeye Bruiser_27861
# Added comment for string#116302
# Added comment for string#116304
# Added comment for string#116306
# Uploaded translations for The Crucible of Carnage The Bloodeye Bruiser_27862
# Added comment for string#116308
# Added comment for string#116310
# Added comment for string#116312
# Added comment for string#150762
# Added comment for string#150764
# Uploaded translations for The Crucible of Carnage The Bloodeye Bruiser_27863
# Added comment for string#116314
# Added comment for string#116316
# Added comment for string#116318
# Added comment for string#150766
# Uploaded translations for The Crucible of Carnage The Deadly Dragonmaw_27864
# Added comment for string#116332
# Added comment for string#116334
# Added comment for string#116336
# Added comment for string#150776
# Added comment for string#150778
# Uploaded translations for The Crucible of Carnage The Wayward Wildhammer_27865
# Added comment for string#116290
# Added comment for string#116292
# Added comment for string#116294
# Added comment for string#150758
# Added comment for string#150760
# Uploaded translations for The Crucible of Carnage Calders Creation_27866
# Added comment for string#116320
# Added comment for string#116322
# Added comment for string#116324
# Added comment for string#150768
# Added comment for string#150770
# Uploaded translations for The Crucible of Carnage The Earl of Evisceration_27867
# Added comment for string#116326
# Added comment for string#116328
# Added comment for string#116330
# Added comment for string#150772
# Added comment for string#150774
# Uploaded translations for The Crucible of Carnage The Twilight Terror_27868
# Added comment for string#115480
# Added comment for string#115482
# Added comment for string#115484
# Added comment for string#150380
# Uploaded translations for Drag em Down_27929
# Added comment for string#115978
# Added comment for string#115980
# Added comment for string#115982
# Added comment for string#150610
# Added comment for string#150612
# Uploaded translations for Paint it Black_27945
# Added comment for string#115210
# Added comment for string#115212
# Added comment for string#115214
# Added comment for string#150252
# Uploaded translations for A Vision of Twilight_27947
# Added comment for string#116590
# Added comment for string#116592
# Added comment for string#116594
# Added comment for string#150894
# Added comment for string#150896
# Uploaded translations for We All Must Sacrifice_27951
# Added comment for string#116356
# Added comment for string#116358
# Added comment for string#116360
# Added comment for string#150792
# Added comment for string#150794
# Uploaded translations for The Eyes Have It_27954
# Added comment for string#115570
# Added comment for string#115572
# Added comment for string#115574
# Added comment for string#150416
# Added comment for string#150418
# Uploaded translations for Eye Spy_27955
# Added comment for string#116368
# Added comment for string#116370
# Added comment for string#116372
# Added comment for string#150800
# Uploaded translations for The Fate of the Doyles_27999
# Added comment for string#115180
# Added comment for string#115182
# Added comment for string#115184
# Added comment for string#150236
# Uploaded translations for A Cowards Due_28001
# Added comment for string#115306
# Added comment for string#115308
# Added comment for string#115310
# Added comment for string#150298
# Uploaded translations for Blood in the Highlands_28038
# Added comment for string#115270
# Added comment for string#115272
# Added comment for string#115274
# Added comment for string#150282
# Added comment for string#150284
# Uploaded translations for Bait and Throttle_28041
# Added comment for string#115714
# Added comment for string#115716
# Added comment for string#115718
# Added comment for string#150486
# Uploaded translations for How to Maim Your Dragon_28043
# Added comment for string#116032
# Added comment for string#116034
# Added comment for string#116036
# Added comment for string#150634
# Added comment for string#150636
# Uploaded translations for Precious Goods_28090
# Added comment for string#115522
# Added comment for string#115524
# Added comment for string#115526
# Added comment for string#150398
# Uploaded translations for Easy Pickings_28091
# Added comment for string#115720
# Added comment for string#115722
# Added comment for string#115724
# Added comment for string#150488
# Added comment for string#150490
# Uploaded translations for If The Key Fits_28092
# Added comment for string#116044
# Added comment for string#116046
# Added comment for string#116048
# Added comment for string#150642
# Added comment for string#150644
# Uploaded translations for Pressing Forward_28093
# Added comment for string#115996
# Added comment for string#115998
# Added comment for string#116000
# Added comment for string#150618
# Uploaded translations for Paving the Way_28094
# Added comment for string#116380
# Added comment for string#116382
# Added comment for string#116384
# Added comment for string#150806
# Uploaded translations for The Gates of Grim Batol_28097
# Added comment for string#115828
# Added comment for string#115830
# Added comment for string#115832
# Added comment for string#150544
# Uploaded translations for Mathias Command_28101
# Added comment for string#115528
# Added comment for string#115530
# Added comment for string#115532
# Added comment for string#150400
# Uploaded translations for Easy Pickings_28103
# Added comment for string#116038
# Added comment for string#116040
# Added comment for string#116042
# Added comment for string#150638
# Added comment for string#150640
# Uploaded translations for Precious Goods_28104
# Added comment for string#116002
# Added comment for string#116004
# Added comment for string#116006
# Added comment for string#153944
# Added comment for string#150620
# Uploaded translations for Paving the Way_28107
# Added comment for string#115726
# Added comment for string#115728
# Added comment for string#115730
# Added comment for string#150492
# Added comment for string#150494
# Uploaded translations for If The Key Fits_28108
# Added comment for string#116050
# Added comment for string#116052
# Added comment for string#116054
# Added comment for string#150646
# Added comment for string#150648
# Uploaded translations for Pressing Forward_28109
# Added comment for string#116338
# Added comment for string#116340
# Added comment for string#116342
# Added comment for string#150780
# Added comment for string#150782
# Uploaded translations for The Demon Chain_28123
# Added comment for string#115660
# Added comment for string#115662
# Added comment for string#115664
# Added comment for string#150462
# Added comment for string#150464
# Uploaded translations for Fury Unbound_28133
# Added comment for string#116056
# Added comment for string#116058
# Added comment for string#116060
# Added comment for string#150650
# Added comment for string#150652
# Uploaded translations for Purple is Your Color_28147
# Added comment for string#116626
# Added comment for string#116628
# Added comment for string#116630
# Added comment for string#150914
# Added comment for string#150916
# Uploaded translations for Whispers in the Wind_28149
# Added comment for string#115504
# Added comment for string#115506
# Added comment for string#115508
# Added comment for string#150390
# Uploaded translations for Dressed to Kill_28151
# Added comment for string#116494
# Added comment for string#116496
# Added comment for string#116498
# Added comment for string#150856
# Added comment for string#150858
# Uploaded translations for Thogs Nightlight_28166
# Added comment for string#115924
# Added comment for string#115926
# Added comment for string#115928
# Added comment for string#150582
# Added comment for string#150584
# Uploaded translations for Night Terrors_28170
# Added comment for string#115228
# Added comment for string#115230
# Added comment for string#115232
# Added comment for string#150260
# Uploaded translations for And the Sky Streaked Red_28171
# Added comment for string#115294
# Added comment for string#115296
# Added comment for string#115298
# Added comment for string#150294
# Uploaded translations for Blackout_28173
# Added comment for string#116134
# Added comment for string#116136
# Added comment for string#116138
# Added comment for string#150696
# Added comment for string#150698
# Uploaded translations for Shining Through the Dark_28175
# Added comment for string#115630
# Added comment for string#115632
# Added comment for string#115634
# Added comment for string#150450
# Added comment for string#150452
# Uploaded translations for Following the Young Home_28176
# Added comment for string#115192
# Added comment for string#115194
# Added comment for string#115196
# Added comment for string#150242
# Uploaded translations for A Fitting End_28191
# Added comment for string#116272
# Added comment for string#116274
# Added comment for string#116276
# Added comment for string#150750
# Added comment for string#150752
# Uploaded translations for Tempered in Elemental Flame_28211
# Added comment for string#115708
# Added comment for string#115710
# Added comment for string#115712
# Added comment for string#150482
# Added comment for string#150484
# Uploaded translations for Hot Stuff_28212
# Added comment for string#116026
# Added comment for string#116028
# Added comment for string#116030
# Added comment for string#150630
# Added comment for string#150632
# Uploaded translations for Potential Energy_28215
# Added comment for string#115822
# Added comment for string#115824
# Added comment for string#115826
# Added comment for string#150540
# Added comment for string#150542
# Uploaded translations for Magmalord Falthazar_28216
# Added comment for string#116404
# Added comment for string#116406
# Added comment for string#116408
# Uploaded translations for The Lost Brother_28233
# Added comment for string#116488
# Added comment for string#116490
# Added comment for string#116492
# Added comment for string#150852
# Added comment for string#150854
# Uploaded translations for They Took Me Pants_28234
# Added comment for string#115216
# Added comment for string#115218
# Added comment for string#115220
# Added comment for string#150254
# Uploaded translations for A Vision of Twilight_28241
# Added comment for string#116596
# Added comment for string#116598
# Added comment for string#116600
# Added comment for string#150898
# Added comment for string#150900
# Uploaded translations for We All Must Sacrifice_28242
# Added comment for string#116362
# Added comment for string#116364
# Added comment for string#116366
# Added comment for string#150796
# Added comment for string#150798
# Uploaded translations for The Eyes Have It_28243
# Added comment for string#115576
# Added comment for string#115578
# Added comment for string#115580
# Added comment for string#150420
# Added comment for string#150422
# Uploaded translations for Eye Spy_28244
# Added comment for string#115798
# Added comment for string#115800
# Added comment for string#115802
# Added comment for string#150530
# Uploaded translations for Last of Her Kind_28247
# Added comment for string#116548
# Added comment for string#116550
# Added comment for string#116552
# Added comment for string#150874
# Uploaded translations for Victors Point_28248
# Added comment for string#115396
# Added comment for string#115398
# Added comment for string#115400
# Added comment for string#150338
# Uploaded translations for Crushblow_28249
# Added comment for string#116266
# Added comment for string#116268
# Added comment for string#116270
# Added comment for string#150748
# Uploaded translations for Tear Them From the Sky_28280
# Added comment for string#115804
# Added comment for string#115806
# Added comment for string#115808
# Added comment for string#150526
# Added comment for string#150528
# Uploaded translations for Last Stand at Thundermar_28281
# Added comment for string#115900
# Added comment for string#115902
# Added comment for string#115904
# Added comment for string#150566
# Added comment for string#150568
# Uploaded translations for Narkrall The Drake-Tamer_28282
# Added comment for string#116398
# Added comment for string#116400
# Added comment for string#116402
# Added comment for string#150812
# Uploaded translations for The Kirthaven Summit_28294
# Added comment for string#116284
# Added comment for string#116286
# Added comment for string#116288
# Added comment for string#150754
# Uploaded translations for The Bachelor_28346
# Added comment for string#115882
# Added comment for string#115884
# Added comment for string#115886
# Added comment for string#150562
# Uploaded translations for My Sister Fanny_28369
# Added comment for string#116080
# Added comment for string#116082
# Added comment for string#116084
# Added comment for string#150662
# Uploaded translations for Rescue at Glopguts Hollow_28377
# Added comment for string#115600
# Added comment for string#115602
# Added comment for string#115604
# Added comment for string#150436
# Added comment for string#150438
# Uploaded translations for Find Fanny_28378
# Added comment for string#115948
# Added comment for string#115950
# Added comment for string#115952
# Added comment for string#153942
# Added comment for string#150594
# Uploaded translations for Ogre Bashin_28379
# Added comment for string#116278
# Added comment for string#116280
# Added comment for string#116282
# Added comment for string#150756
# Uploaded translations for The Bachelorette_28407
# Added comment for string#116224
# Added comment for string#116226
# Added comment for string#116228
# Added comment for string#150728
# Added comment for string#150730
# Uploaded translations for Something Bold_28408
# Added comment for string#116230
# Added comment for string#116232
# Added comment for string#116234
# Added comment for string#150732
# Uploaded translations for Something Brewed_28409
# Added comment for string#116242
# Added comment for string#116244
# Added comment for string#116246
# Added comment for string#150738
# Added comment for string#150740
# Uploaded translations for Something Stolen_28410
# Added comment for string#116236
# Added comment for string#116238
# Added comment for string#116240
# Added comment for string#150734
# Added comment for string#150736
# Uploaded translations for Something Stewed_28411
# Added comment for string#116650
# Added comment for string#116652
# Added comment for string#116654
# Added comment for string#153948
# Added comment for string#150930
# Uploaded translations for Words and Music By..._28413
# Added comment for string#115780
# Added comment for string#115782
# Added comment for string#115784
# Added comment for string#150518
# Added comment for string#150520
# Uploaded translations for Krazzworks_28583
# Added comment for string#116068
# Added comment for string#116070
# Added comment for string#116072
# Added comment for string#150656
# Added comment for string#150658
# Uploaded translations for Quality Construction_28584
# Added comment for string#116014
# Added comment for string#116016
# Added comment for string#116018
# Added comment for string#150624
# Added comment for string#150626
# Uploaded translations for Pool Pony Rescue_28586
# Added comment for string#116638
# Added comment for string#116640
# Added comment for string#116642
# Added comment for string#150922
# Added comment for string#150924
# Uploaded translations for Wildhammer Infestation_28588
# Added comment for string#115564
# Added comment for string#115566
# Added comment for string#115568
# Added comment for string#150414
# Uploaded translations for Everything But the Kitchen Sink_28589
# Added comment for string#116074
# Added comment for string#116076
# Added comment for string#116078
# Added comment for string#150660
# Uploaded translations for Reprisal_28590
# Added comment for string#115942
# Added comment for string#115944
# Added comment for string#115946
# Added comment for string#150592
# Uploaded translations for Off The Wall_28591
# Added comment for string#115984
# Added comment for string#115986
# Added comment for string#115988
# Added comment for string#150614
# Uploaded translations for Parting Packages_28592
# Added comment for string#115936
# Added comment for string#115938
# Added comment for string#115940
# Added comment for string#150588
# Added comment for string#150590
# Uploaded translations for Of Utmost Importance_28593
# Added comment for string#115684
# Added comment for string#115686
# Added comment for string#115688
# Added comment for string#150472
# Added comment for string#150474
# Uploaded translations for Highbank Crybank_28594
# Added comment for string#115774
# Added comment for string#115776
# Added comment for string#115778
# Added comment for string#150514
# Added comment for string#150516
# Uploaded translations for Krazz Works_28595
# Added comment for string#116608
# Added comment for string#116610
# Added comment for string#116612
# Added comment for string#150906
# Added comment for string#150908
# Uploaded translations for Welcome to Highbank_28596
# Added comment for string#115348
# Added comment for string#115350
# Added comment for string#115352
# Added comment for string#150314
# Added comment for string#150316
# Uploaded translations for Burnin at Both Ends_28597
# Added comment for string#115222
# Added comment for string#115224
# Added comment for string#115226
# Added comment for string#150256
# Added comment for string#150258
# Uploaded translations for Aiming High_28598
# Added comment for string#115786
# Added comment for string#115788
# Added comment for string#115790
# Added comment for string#150522
# Uploaded translations for Kurdrans Waitin_28599
# Added comment for string#116632
# Added comment for string#116634
# Added comment for string#116636
# Added comment for string#150918
# Added comment for string#150920
# Uploaded translations for Wild Wild Wildhammer Wedding_28655
# Added comment for string#115546
# Added comment for string#115548
# Added comment for string#115550
# Added comment for string#150408
# Uploaded translations for Enter the Dragon Queen_28712
# Added comment for string#115276
# Added comment for string#115278
# Added comment for string#115280
# Added comment for string#150286
# Added comment for string#150288
# Uploaded translations for Battle of Life and Death_28758
# Added comment for string#116518
# Added comment for string#116520
# Added comment for string#116522
# Added comment for string#150868
# Uploaded translations for Twilight Shores_28832
# Added comment for string#115762
# Added comment for string#115764
# Added comment for string#115766
# Added comment for string#150506
# Added comment for string#150508
# Uploaded translations for Keeping the Dragonmaw at Bay_28860
# Added comment for string#115594
# Added comment for string#115596
# Added comment for string#115598
# Added comment for string#150432
# Added comment for string#150434
# Uploaded translations for Fight Like a Wildhammer_28861
# Added comment for string#115918
# Added comment for string#115920
# Added comment for string#115922
# Added comment for string#150578
# Added comment for string#150580
# Uploaded translations for Never Leave a Dinner Behind_28862
# Added comment for string#116560
# Added comment for string#116562
# Added comment for string#116564
# Added comment for string#150880
# Uploaded translations for Warlord Halthar is Back_28863
# Added comment for string#115282
# Added comment for string#115284
# Added comment for string#115286
# Added comment for string#150290
# Uploaded translations for Beer Run_28864
# Added comment for string#115408
# Added comment for string#115410
# Added comment for string#115412
# Added comment for string#150344
# Added comment for string#150346
# Uploaded translations for Crushing the Wildhammer_28871
# Added comment for string#116512
# Added comment for string#116514
# Added comment for string#116516
# Added comment for string#150866
# Uploaded translations for Total War_28872
# Added comment for string#115234
# Added comment for string#115236
# Added comment for string#115238
# Added comment for string#150262
# Added comment for string#150264
# Uploaded translations for Another Maw to Feed_28873
# Added comment for string#115702
# Added comment for string#115704
# Added comment for string#115706
# Added comment for string#150480
# Uploaded translations for Hook em High_28874
# Added comment for string#115330
# Added comment for string#115332
# Added comment for string#115334
# Added comment for string#150306
# Uploaded translations for Bring Down the High Shaman_28875
# Added comment for string#115870
# Added comment for string#115872
# Added comment for string#115874
# Added comment for string#150556
# Uploaded translations for Mr. Goldmines Wild Ride_28885
